# %%
import shelve
import time
from datetime import datetime

_cache = shelve.open("cache")
TIMEOUT = 86400 * 30
def is_expired(dt, limit_seconds = 86400*7):
    return (datetime.now() - datetime.fromisoformat(dt)).seconds > limit_seconds

def clear_cache():
    _cache.clear()
    _cache.sync()

def cache(fun):
    def to_url(*args, **kwargs):
        url = kwargs['url'] if 'url' in kwargs else args[0]
        params_dict = kwargs['params'] if 'params' in kwargs else args[1] if len(args) > 1 else dict()
        params = '&'.join([str(k) + '=' + str(v) for (k,v) in params_dict.items()])
        return url + "?" + params
        
    def wrapper(*args, **kwargs):
        url = to_url(*args, **kwargs)
        print("url: " + url)
        if (url not in _cache):
            print("Not cached " + url)
            result = fun(*args, **kwargs)
            _cache[url] = {
                'url': url,
                'timestamp': datetime.now().isoformat(),
                'result': result
            }
            _cache.sync()
            return result
        
        result = _cache[url]
        if(not is_expired(result['timestamp'], TIMEOUT)):
            print("Cached " + url)
            return result['result']
        
        print("Expired " + url)
        result = fun(*args, **kwargs)
        _cache[url] = {
            'url': url,
            'timestamp': datetime.now().isoformat(),
            'result': result
        }
        _cache.sync()
        return result
        
    return wrapper

# %%
# Create schema
import sqlite3
conn = sqlite3.connect('moex.db')
try:
    c = conn.cursor()
    c.execute(
        '''CREATE TABLE IF NOT EXISTS engines (
            id int, 
            name text, 
            title text
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS markets (
            id int, 
            trade_engine_id int,
            trade_engine_name text, 
            trade_engine_title text,
            market_name text,
            market_title text,
            market_id int,
            marketplace text
        )''')

    c.execute(
        '''CREATE TABLE IF NOT EXISTS boards (
            id int,
            board_group_id int,
            engine_id int,
            market_id int,
            boardid int,
            board_title text,
            is_traded int,
            has_candles int,
            is_primary int
        )''')

    c.execute(
        '''CREATE TABLE IF NOT EXISTS boardgroups (
            id int,
            trade_engine_id int,
            trade_engine_name text,
            trade_engine_title text,
            market_id int,
            market_name text,
            name text,
            title text,
            is_default int,
            board_group_id int,
            is_traded int
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS durations (
            interval int,
            duration int,
            days int,
            title text,
            hint text
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securitytypes (
            id int,
            trade_engine_id int,
            trade_engine_name text,
            trade_engine_title text,
            security_type_name text,
            security_type_title text
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securitygroups (
            id int,
            name text,
            title text,
            is_hidden int
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securitycollections (
            id int,
            name text,
            title text,
            security_group_id int
        )''')
finally:
    conn.close()

# %%
def fill_engines(engines):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM engines')
        conn.commit()
        for e in engines:
            conn.execute('insert into engines values (?,?,?)',(
                e['id'],
                e['name'],
                e['title']
            ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_markets(markets):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM markets')
        conn.commit()
        for e in markets:                        
            conn.execute('insert into markets values (?,?,?,?,?,?,?,?)',(
                e['id'],
                e['trade_engine_id'],
                e['trade_engine_name'],
                e['trade_engine_title'],
                e['market_name'],
                e['market_title'],
                e['market_id'],
                e['marketplace']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_boards(boards):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM boards')
        conn.commit()
        for e in boards:
            conn.execute('insert into boards values (?,?,?,?,?,?,?,?,?)',(
                e['id'],
                e['board_group_id'],
                e['engine_id'],
                e['market_id'],
                e['boardid'],
                e['board_title'],
                e['is_traded'],
                e['has_candles'],
                e['is_primary']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_boardgroups(boardgroups):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM boardgroups')
        conn.commit()
        for e in boardgroups:
            conn.execute('insert into boardgroups values (?,?,?,?,?,?,?,?,?,?,?)',(
                e['id'],
                e['trade_engine_id'],
                e['trade_engine_name'],
                e['trade_engine_title'],
                e['market_id'],
                e['market_name'],
                e['name'],
                e['title'],
                e['is_default'],
                e['board_group_id'],
                e['is_traded']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_durations(durations):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM durations')
        conn.commit()
        for e in durations:
            conn.execute('insert into durations values (?,?,?,?,?)',(
                e['interval'],
                e['duration'],
                e['days'],
                e['title'],
                e['hint']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securitytypes(securitytypes):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securitytypes')
        conn.commit()
        for e in securitytypes:
            conn.execute('insert into securitytypes values (?,?,?,?,?,?)',(
                e['id'],
                e['trade_engine_id'],
                e['trade_engine_name'],
                e['trade_engine_title'],
                e['security_type_name'],
                e['security_type_title']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securitygroups(securitygroups):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securitygroups')
        conn.commit()
        for e in securitygroups:
            conn.execute('insert into securitygroups values (?,?,?,?)',(
                e['id'],
                e['name'],
                e['title'],
                e['is_hidden']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securitycollections(securitycollections):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securitycollections')
        conn.commit()
        for e in securitycollections:
            conn.execute('insert into securitycollections values (?,?,?,?)',(
                e['id'],
                e['name'],
                e['title'],
                e['security_group_id']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
m = moex_markets()
print('engines ', m[1]['engines'][1][0])
fill_engines(m[1]['engines'][1])

print('markets ', m[1]['markets'][1][0])
fill_markets(m[1]['markets'][1])

print('boards ', m[1]['boards'][1][0])
fill_boards(m[1]['boards'][1])

print('boardgroups ', m[1]['boardgroups'][1][0])
fill_boardgroups(m[1]['boardgroups'][1])

print('durations ', m[1]['durations'][1][0])
fill_durations(m[1]['durations'][1])

print('securitytypes ', m[1]['securitytypes'][1][0])
fill_securitytypes(m[1]['securitytypes'][1])

print('securitygroups ', m[1]['securitygroups'][1][0])
fill_securitygroups(m[1]['securitygroups'][1])

print('securitycollections ', m[1]['securitycollections'][1][0])
fill_securitycollections(m[1]['securitycollections'][1])
# Out:
# url: http://iss.moex.com/iss/index.json?iss.json=extended
# Cached http://iss.moex.com/iss/index.json?iss.json=extended
# engines  {'id': 1, 'name': 'stock', 'title': 'Фондовый рынок и рынок депозитов'}
# markets  {'id': 5, 'trade_engine_id': 1, 'trade_engine_name': 'stock', 'trade_engine_title': 'Фондовый рынок и рынок депозитов', 'market_name': 'index', 'market_title': 'Индексы фондового рынка', 'market_id': 5, 'marketplace': 'INDICES'}
# boards  {'id': 260, 'board_group_id': 99, 'engine_id': 1, 'market_id': 1, 'boardid': 'EQTD', 'board_title': 'Т0 ETF (USD) - безадрес.', 'is_traded': 1, 'has_candles': 1, 'is_primary': 0}
# boardgroups  {'id': 9, 'trade_engine_id': 1, 'trade_engine_name': 'stock', 'trade_engine_title': 'Фондовый рынок и рынок депозитов', 'market_id': 5, 'market_name': 'index', 'name': 'stock_index', 'title': 'Индексы', 'is_default': 1, 'board_group_id': 9, 'is_traded': 1}
# durations  {'interval': 1, 'duration': 60, 'days': None, 'title': 'минута', 'hint': '1м'}
# securitytypes  {'id': 3, 'trade_engine_id': 1, 'trade_engine_name': 'stock', 'trade_engine_title': 'Фондовый рынок и рынок депозитов', 'security_type_name': 'common_share', 'security_type_title': 'Акция обыкновенная'}
# securitygroups  {'id': 12, 'name': 'stock_index', 'title': 'Индексы', 'is_hidden': 0}
# securitycollections  {'id': 72, 'name': 'stock_index_all', 'title': 'Все индексы', 'security_group_id': 12}

# %%
import requests
@cache
def get(url, params = None):
    return requests.get(url, params).json()

# %%
clear_cache()

# %%
# For testing
@cache
def do(url, params = {}):
    return params
print(do(url="123", params={"a": 1, "b": 2}))
print(do(url="456", params={"a": 1, "b": 2}))
print(do("123", {"a": 1, "b": 2}))
time.sleep(2)
print(do(url="123"))
# Out:
# url: 123?a=1&b=2
# Cached 123?a=1&b=2
# {'url': '123?a=1&b=2', 'timestamp': '2020-05-13T19:23:09.441742', 'result': {'a': 1, 'b': 2}}
# url: 456?a=1&b=2
# Cached 456?a=1&b=2
# {'url': '456?a=1&b=2', 'timestamp': '2020-05-13T19:23:09.457036', 'result': {'a': 1, 'b': 2}}
# url: 123?a=1&b=2
# Cached 123?a=1&b=2
# {'url': '123?a=1&b=2', 'timestamp': '2020-05-13T19:23:09.441742', 'result': {'a': 1, 'b': 2}}
# url: 123?
# Cached 123?
# {'url': '123?', 'timestamp': '2020-05-13T19:24:18.867112', 'result': {}}

# %%
def moex_markets():
    return get('http://iss.moex.com/iss/index.json', {'iss.json': 'extended'})

# %%
def securities():
    start = 0
    limit = 100
    count = 1 # initial truish value
    results = []
    while count > 0:
        batch = get('http://iss.moex.com/iss/securities.json', {'iss.json': 'extended', 'limit': limit, 'start':start})
        results.append(batch)
        count = len(batch['securities']['data'])
        print ("From " + str(start) + "took " + str(count))
        start += count
    return results

# %%
x = securities()
# Out:
# url: http://iss.moex.com/iss/securities.json?limit=100&start=0
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=0
# From 0took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=100
# From 100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=200
# From 200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=300
# From 300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=400
# From 400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=500
# From 500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=600
# From 600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=700
# From 700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=800
# From 800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=900
# From 900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1000
# From 1000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1100
# From 1100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1200
# From 1200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1300
# From 1300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1400
# From 1400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1500
# From 1500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1600
# From 1600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1700
# From 1700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1800
# From 1800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=1900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=1900
# From 1900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2000
# From 2000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2100
# From 2100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2200
# From 2200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2300
# From 2300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2400
# From 2400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2500
# From 2500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2600
# From 2600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2700
# From 2700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2800
# From 2800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=2900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=2900
# From 2900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3000
# From 3000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3100
# From 3100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3200
# From 3200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3300
# From 3300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3400
# From 3400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3500
# From 3500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3600
# From 3600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3700
# From 3700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3800
# From 3800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=3900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=3900
# From 3900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4000
# From 4000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4100
# From 4100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4200
# From 4200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4300
# From 4300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4400
# From 4400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4500
# From 4500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4600
# From 4600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4700
# From 4700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4800
# From 4800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=4900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=4900
# From 4900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5000
# From 5000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5100
# From 5100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5200
# From 5200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5300
# From 5300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5400
# From 5400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5500
# From 5500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5600
# From 5600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5700
# From 5700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5800
# From 5800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=5900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=5900
# From 5900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6000
# From 6000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6100
# From 6100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6200
# From 6200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6300
# From 6300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6400
# From 6400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6500
# From 6500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6600
# From 6600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6700
# From 6700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6800
# From 6800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=6900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=6900
# From 6900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7000
# From 7000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7100
# From 7100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7200
# From 7200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7300
# From 7300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7400
# From 7400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7500
# From 7500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7600
# From 7600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7700
# From 7700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7800
# From 7800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=7900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=7900
# From 7900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8000
# From 8000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8100
# From 8100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8200
# From 8200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8300
# From 8300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8400
# From 8400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8500
# From 8500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8600
# From 8600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8700
# From 8700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8800
# From 8800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=8900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=8900
# From 8900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9000
# From 9000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9100
# From 9100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9200
# From 9200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9300
# From 9300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9400
# From 9400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9500
# From 9500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9600
# From 9600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9700
# From 9700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9800
# From 9800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=9900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=9900
# From 9900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10000
# From 10000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10100
# From 10100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10200
# From 10200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10300
# From 10300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10400
# From 10400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10500
# From 10500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10600
# From 10600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10700
# From 10700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10800
# From 10800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=10900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=10900
# From 10900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11000
# From 11000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11100
# From 11100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11200
# From 11200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11300
# From 11300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11400
# From 11400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11500
# From 11500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11600
# From 11600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11700
# From 11700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11800
# From 11800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=11900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=11900
# From 11900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12000
# From 12000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12100
# From 12100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12200
# From 12200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12300
# From 12300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12400
# From 12400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12500
# From 12500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12600
# From 12600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12700
# From 12700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12800
# From 12800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=12900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=12900
# From 12900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13000
# From 13000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13100
# From 13100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13200
# From 13200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13300
# From 13300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13400
# From 13400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13500
# From 13500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13600
# From 13600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13700
# From 13700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13800
# From 13800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=13900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=13900
# From 13900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14000
# From 14000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14100
# From 14100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14200
# From 14200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14300
# From 14300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14400
# From 14400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14500
# From 14500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14600
# From 14600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14700
# From 14700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14800
# From 14800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=14900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=14900
# From 14900took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15000
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15000
# From 15000took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15100
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15100
# From 15100took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15200
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15200
# From 15200took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15300
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15300
# From 15300took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15400
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15400
# From 15400took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15500
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15500
# From 15500took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15600
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15600
# From 15600took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15700
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15700
# From 15700took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15800
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15800
# From 15800took 100
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15900
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15900
# From 15900took 31
# url: http://iss.moex.com/iss/securities.json?limit=100&start=15931
# Cached http://iss.moex.com/iss/securities.json?limit=100&start=15931
# From 15931took 0

# %%
import json
print(json.dumps(moex_markets(), indent=2).encode('latin1').decode('unicode-escape'))
# Out:
# url: http://iss.moex.com/iss/index.json?iss.json=extended
# Not cached http://iss.moex.com/iss/index.json?iss.json=extended
# [
#   {
#     "charsetinfo": {
#       "name": "utf-8"
#     }
#   },
#   {
#     "engines": [
#       {
#         "metadata": {
#           "id": {
#             "type": "int32"
#           },
#           "name": {
#             "type": "string",
#             "bytes": 45,
#             "max_size": 0
#           },
#           "title": {
#             "type": "string",
#             "bytes": 765,
#             "max_size": 0
#           }
#         }
#       },
#       [
#         {
#           "id": 1,
#           "name": "stock",
#           "title": "Фондовый рынок и рынок депозитов"
#         },
#         {
#           "id": 2,
#           "name": "state",
#           "title": "Рынок ГЦБ (размещение)"
#         },
#         {
#           "id": 3,
#           "name": "currency",
#           "title": "Валютный рынок"
#         },
#         {
#           "id": 4,
#           "name": "futures",
#           "title": "Срочный рынок"
#         },
#         {
#           "id": 5,
#           "name": "commodity",
#           "title": "Товарный рынок"
#         },
#         {
#           "id": 6,
#           "name": "interventions",
#           "title": "Товарные интервенции"
#         },
#         {
#           "id": 7,
#           "name": "offboard",
#           "title": "ОТС-система"
#         }
#       ]
#     ],
#     "markets": [
#       {
#         "metadata": {
#           "id": {
#             "type": "int32"
#           },
#           "trade_engine_id": {
#             "type": "int32"
#           },
#           "trade_engine_name": {
#             "type": "string",
#             "bytes": 45,
#             "max_size": 0
#           },
#           "trade_engine_title": {
#             "type": "string",
#             "bytes": 765,
#             "max_size": 0
#           },
#           "market_name": {
#             "type": "string",
#             "bytes": 45,
#             "max_size": 0
#           },
#           "market_title": {
#             "type": "string",
#             "bytes": 765,
#             "max_size": 0
#           },
#           "market_id": {
#             "type": "int32"
#           },
#           "marketplace": {
#             "type": "string",
#             "bytes": 48,
#             "max_size": 0
#           }
#         }
#       },
#       [
#         {
#           "id": 5,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "index",
#           "market_title": "Индексы фондового рынка",
#           "market_id": 5,
#           "marketplace": "INDICES"
#         },
#         {
#           "id": 1,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "shares",
#           "market_title": "Рынок акций",
#           "market_id": 1,
#           "marketplace": "MXSE"
#         },
#         {
#           "id": 2,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "bonds",
#           "market_title": "Рынок облигаций",
#           "market_id": 2,
#           "marketplace": "MXSE"
#         },
#         {
#           "id": 4,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "ndm",
#           "market_title": "Режим переговорных сделок",
#           "market_id": 4,
#           "marketplace": null
#         },
#         {
#           "id": 29,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "otc",
#           "market_title": "ОТС",
#           "market_id": 29,
#           "marketplace": null
#         },
#         {
#           "id": 27,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "ccp",
#           "market_title": "РЕПО с ЦК",
#           "market_id": 27,
#           "marketplace": "MXSE"
#         },
#         {
#           "id": 35,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "deposit",
#           "market_title": "Депозиты с ЦК",
#           "market_id": 35,
#           "marketplace": null
#         },
#         {
#           "id": 3,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "repo",
#           "market_title": "Рынок сделок РЕПО",
#           "market_id": 3,
#           "marketplace": null
#         },
#         {
#           "id": 28,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "qnv",
#           "market_title": "Квал. инвесторы",
#           "market_id": 28,
#           "marketplace": null
#         },
#         {
#           "id": 36,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "mamc",
#           "market_title": "Мультивалютный рынок смешанных активов",
#           "market_id": 36,
#           "marketplace": null
#         },
#         {
#           "id": 33,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "moexboard",
#           "market_title": "MOEX Board",
#           "market_id": 33,
#           "marketplace": null
#         },
#         {
#           "id": 21,
#           "trade_engine_id": 3,
#           "trade_engine_name": "currency",
#           "trade_engine_title": "Валютный рынок",
#           "market_name": "basket",
#           "market_title": "Бивалютная корзина",
#           "market_id": 21,
#           "marketplace": null
#         },
#         {
#           "id": 10,
#           "trade_engine_id": 3,
#           "trade_engine_name": "currency",
#           "trade_engine_title": "Валютный рынок",
#           "market_name": "selt",
#           "market_title": "Биржевые сделки с ЦК",
#           "market_id": 10,
#           "marketplace": "MXCX"
#         },
#         {
#           "id": 34,
#           "trade_engine_id": 3,
#           "trade_engine_name": "currency",
#           "trade_engine_title": "Валютный рынок",
#           "market_name": "futures",
#           "market_title": "Поставочные фьючерсы",
#           "market_id": 34,
#           "marketplace": "MXCX"
#         },
#         {
#           "id": 41,
#           "trade_engine_id": 3,
#           "trade_engine_name": "currency",
#           "trade_engine_title": "Валютный рынок",
#           "market_name": "index",
#           "market_title": "Валютный фиксинг",
#           "market_id": 41,
#           "marketplace": "FIXING"
#         },
#         {
#           "id": 12,
#           "trade_engine_id": 4,
#           "trade_engine_name": "futures",
#           "trade_engine_title": "Срочный рынок",
#           "market_name": "main",
#           "market_title": "Срочные инструменты",
#           "market_id": 12,
#           "marketplace": null
#         },
#         {
#           "id": 22,
#           "trade_engine_id": 4,
#           "trade_engine_name": "futures",
#           "trade_engine_title": "Срочный рынок",
#           "market_name": "forts",
#           "market_title": "ФОРТС",
#           "market_id": 22,
#           "marketplace": "FORTS"
#         },
#         {
#           "id": 24,
#           "trade_engine_id": 4,
#           "trade_engine_name": "futures",
#           "trade_engine_title": "Срочный рынок",
#           "market_name": "options",
#           "market_title": "Опционы ФОРТС",
#           "market_id": 24,
#           "marketplace": "OPTIONS"
#         },
#         {
#           "id": 37,
#           "trade_engine_id": 4,
#           "trade_engine_name": "futures",
#           "trade_engine_title": "Срочный рынок",
#           "market_name": "fortsiqs",
#           "market_title": "Фьючерсы IQS",
#           "market_id": 37,
#           "marketplace": null
#         },
#         {
#           "id": 38,
#           "trade_engine_id": 4,
#           "trade_engine_name": "futures",
#           "trade_engine_title": "Срочный рынок",
#           "market_name": "optionsiqs",
#           "market_title": "Опционы IQS",
#           "market_id": 38,
#           "marketplace": null
#         },
#         {
#           "id": 9,
#           "trade_engine_id": 2,
#           "trade_engine_name": "state",
#           "trade_engine_title": "Рынок ГЦБ (размещение)",
#           "market_name": "index",
#           "market_title": "Индексы ГКО/ОФЗ",
#           "market_id": 9,
#           "marketplace": null
#         },
#         {
#           "id": 6,
#           "trade_engine_id": 2,
#           "trade_engine_name": "state",
#           "trade_engine_title": "Рынок ГЦБ (размещение)",
#           "market_name": "bonds",
#           "market_title": "Облигации ГЦБ",
#           "market_id": 6,
#           "marketplace": null
#         },
#         {
#           "id": 7,
#           "trade_engine_id": 2,
#           "trade_engine_name": "state",
#           "trade_engine_title": "Рынок ГЦБ (размещение)",
#           "market_name": "repo",
#           "market_title": "Междилерское РЕПО",
#           "market_id": 7,
#           "marketplace": null
#         },
#         {
#           "id": 8,
#           "trade_engine_id": 2,
#           "trade_engine_name": "state",
#           "trade_engine_title": "Рынок ГЦБ (размещение)",
#           "market_name": "ndm",
#           "market_title": "Внесистемные сделки",
#           "market_id": 8,
#           "marketplace": null
#         },
#         {
#           "id": 39,
#           "trade_engine_id": 7,
#           "trade_engine_name": "offboard",
#           "trade_engine_title": "ОТС-система",
#           "market_name": "bonds",
#           "market_title": "Облигации",
#           "market_id": 39,
#           "marketplace": null
#         },
#         {
#           "id": 18,
#           "trade_engine_id": 5,
#           "trade_engine_name": "commodity",
#           "trade_engine_title": "Товарный рынок",
#           "market_name": "futures",
#           "market_title": "Секция стандартных контрактов АО НТБ",
#           "market_id": 18,
#           "marketplace": null
#         },
#         {
#           "id": 20,
#           "trade_engine_id": 6,
#           "trade_engine_name": "interventions",
#           "trade_engine_title": "Товарные интервенции",
#           "market_name": "grain",
#           "market_title": "Интервенции по зерну",
#           "market_id": 20,
#           "marketplace": null
#         },
#         {
#           "id": 23,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "standard",
#           "market_title": "Standard",
#           "market_id": 23,
#           "marketplace": null
#         },
#         {
#           "id": 25,
#           "trade_engine_id": 1,
#           "trade_engine_name": "stock",
#           "trade_engine_title": "Фондовый рынок и рынок депозитов",
#           "market_name": "classica",
#           "market_title": "Classica",
#           "market_id": 25,
#           "marketplace": null
#         }
#       ]
#     ],
#     "boards": [
#       {
#         "metadata": {
#           "id": {
#             "type": "int32"
#           },
#           "board_group_id": {
#             "type": "int32"
#           },
#           "engine_id": {
#             "type": "int32"
#           },
#           "market_id": {
#             "type": "int32"
#           },
#           "boardid": {
#             "type": "string",
#             "bytes": 12,
#             "max_size": 0
#           },
#           "board_title": {
#             "type": "string",
#             "bytes": 381,
#             "max_size": 0
#           },
#           "is_traded": {
#             "type": "int32"
#           },
#           "has_candles": {
#             "type": "int32"
#           },
#           "is_primary": {
#             "type": "int32"
#           }
#         }
#       },
#       [
#         {
#           "id": 260,
#           "board_group_id": 99,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQTD",
#           "board_title": "Т0 ETF (USD) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 177,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQIF",
#           "board_title": "Т+: Паи - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 178,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQTF",
#           "board_title": "Т+: ETF - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 129,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQBR",
#           "board_title": "Т+: Акции и ДР - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 130,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQBS",
#           "board_title": "Т+: А2-Акции и паи - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 131,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQNL",
#           "board_title": "Т+: Б-Акции и паи - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 132,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQLV",
#           "board_title": "Т+: В-Акции и ДР - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 133,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQLI",
#           "board_title": "Т+: И-Акции - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 134,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQNE",
#           "board_title": "Т+: Акции, паи и ДР внесписочные - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 224,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQBD",
#           "board_title": "Т+: Акции и ДР (расч. в USD) - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 158,
#           "board_group_id": 57,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQDE",
#           "board_title": "Т+: Акции Д - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 225,
#           "board_group_id": 156,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQTD",
#           "board_title": "Т+: ETF (USD) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 1,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQBR",
#           "board_title": "Основной режим: А1-Акции и паи - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 2,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQBS",
#           "board_title": "Основной режим: А2-Акции и паи - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 4,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQNL",
#           "board_title": "Основной режим: Б-Акции и паи - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 3,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQLV",
#           "board_title": "Основной режим: В-Акции и РДР - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 117,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQDE",
#           "board_title": "Основной режим: Акции Д - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 28,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQLI",
#           "board_title": "Основной режим: И-Акции - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 5,
#           "board_group_id": 6,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQNE",
#           "board_title": "Основной режим: Акции и паи внесписочные - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 281,
#           "board_group_id": 125,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "SPEQ",
#           "board_title": "Поставка по СК (акции)",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 36,
#           "board_group_id": 21,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "SMAL",
#           "board_title": "Т+: Неполные лоты (акции) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 305,
#           "board_group_id": 42,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQDP",
#           "board_title": "Крупные пакеты - Акции - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 100,
#           "board_group_id": 42,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQDP",
#           "board_title": "Крупные пакеты - Акции - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 313,
#           "board_group_id": 157,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQBE",
#           "board_title": "Т+: Акции и ДР (расч. в EUR) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 314,
#           "board_group_id": 158,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "TQTE",
#           "board_title": "Т+: ETF (расч. в EUR) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 315,
#           "board_group_id": 159,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQTU",
#           "board_title": "Т0 ETF (расч. в EUR) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 95,
#           "board_group_id": 30,
#           "engine_id": 1,
#           "market_id": 1,
#           "boardid": "EQCC",
#           "board_title": "ЦК - режим основных торгов - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 226,
#           "board_group_id": 193,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQOD",
#           "board_title": "Т+: Облигации (USD) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 135,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQOB",
#           "board_title": "Т+: Гособлигации - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 136,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQOS",
#           "board_title": "Т+: А2-Облигации - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 137,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQNO",
#           "board_title": "Т+: Б-Облигации - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 138,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQOV",
#           "board_title": "Т+: В-Облигации - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 139,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQNB",
#           "board_title": "Т+: Облигации внесписочные - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 140,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQUS",
#           "board_title": "Т+: Облигации внеспис. в ин.валюте - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 349,
#           "board_group_id": 58,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQCB",
#           "board_title": "Т+: Облигации- безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 179,
#           "board_group_id": 68,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQTC",
#           "board_title": "T+: ETC - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 8,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQOB",
#           "board_title": "Т0 Облигации - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 9,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQOS",
#           "board_title": "Основной режим: А2-Облигации - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 7,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQNO",
#           "board_title": "Основной режим: Б-Облигации - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 29,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQOV",
#           "board_title": "Основной режим: В-Облигации - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 93,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQDB",
#           "board_title": "Основной режим: Облигации Д - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 6,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQNB",
#           "board_title": "Основной режим: Облигации внесписочные - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 88,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQUS",
#           "board_title": "Основной режим: Облигации внеспис. в ин.валюте - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 165,
#           "board_group_id": 7,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQEO",
#           "board_title": "Основной режим: Облигации (EUR) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 119,
#           "board_group_id": 105,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "SPOB",
#           "board_title": "Поставка по ОФЗ",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 176,
#           "board_group_id": 69,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQTC",
#           "board_title": "T0 ETC - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 37,
#           "board_group_id": 67,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQEU",
#           "board_title": "Облигации (USD) - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 228,
#           "board_group_id": 67,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQGO",
#           "board_title": "Облигации (GBP) - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 229,
#           "board_group_id": 67,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "EQYO",
#           "board_title": "Облигации (CNY) - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 122,
#           "board_group_id": 122,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "AUBB",
#           "board_title": "Выкуп: Аукцион - безадрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 121,
#           "board_group_id": 123,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "AUCT",
#           "board_title": "Размещение: Аукцион - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 227,
#           "board_group_id": 77,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQDB",
#           "board_title": "Крупные пакеты: Облигации - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 323,
#           "board_group_id": 167,
#           "engine_id": 1,
#           "market_id": 2,
#           "boardid": "TQDU",
#           "board_title": "Крупные пакеты – Облигации (USD) - безадрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 24,
#           "board_group_id": 201,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPMO",
#           "board_title": "РЕПО-М - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 34,
#           "board_group_id": 1,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPEQ",
#           "board_title": "РЕПО: Акции и паи - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 23,
#           "board_group_id": 95,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPMA",
#           "board_title": "РЕПО c акциями - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 35,
#           "board_group_id": 94,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPEU",
#           "board_title": "РЕПО в ин. валюте (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 162,
#           "board_group_id": 94,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPUA",
#           "board_title": "РЕПО c акциями (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 163,
#           "board_group_id": 94,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPUO",
#           "board_title": "РЕПО c облигациями (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 164,
#           "board_group_id": 90,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPEO",
#           "board_title": "РЕПО в ин. валюте (EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 254,
#           "board_group_id": 2,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPEY",
#           "board_title": "РЕПО в ин.валюте (CNY) - адрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 238,
#           "board_group_id": 2,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPGO",
#           "board_title": "РЕПО c облигациями (GBP) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 96,
#           "board_group_id": 31,
#           "engine_id": 1,
#           "market_id": 3,
#           "boardid": "RPCC",
#           "board_title": "РЕПО с ЦК - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 173,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTIF",
#           "board_title": "РПС с ЦК: Паи - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 174,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTTF",
#           "board_title": "РПС с ЦК: ETF - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 175,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTTC",
#           "board_title": "РПС с ЦК: ETC - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 142,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTEQ",
#           "board_title": "РПС с ЦК: Акции и ДР - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 143,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTES",
#           "board_title": "РПС С ЦК: А2-Акции и паи - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 144,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTNL",
#           "board_title": "РПС С ЦК: Б-Акции и паи - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 145,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTLV",
#           "board_title": "РПС С ЦК: В-Акции и ДР - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 146,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTLI",
#           "board_title": "РПС С ЦК: И-Акции - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 147,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTNE",
#           "board_title": "РПС С ЦК: Акции, паи и ДР внесписочные - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 148,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTOB",
#           "board_title": "РПС с ЦК: Облигации - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 149,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTOS",
#           "board_title": "РПС С ЦК: А2-Облигации - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 150,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTNO",
#           "board_title": "РПС С ЦК: Б-Облигации - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 151,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTOV",
#           "board_title": "РПС С ЦК: В-Облигации - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 152,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTNB",
#           "board_title": "РПС С ЦК: Облигации внесписочные - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 153,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTUS",
#           "board_title": "РПС С ЦК: Облигации в ин.валюте - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 154,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTEU",
#           "board_title": "РПС с ЦК: Облигации (USD) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 161,
#           "board_group_id": 59,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTDE",
#           "board_title": "РПС с ЦК: Акции Д - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 233,
#           "board_group_id": 74,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSSD",
#           "board_title": "РПС: Акции и ДР (USD) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 234,
#           "board_group_id": 74,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSTD",
#           "board_title": "РПС: ETF (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 170,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSIF",
#           "board_title": "РПС: Паи - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 171,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSTF",
#           "board_title": "РПС: ETF - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 172,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSTC",
#           "board_title": "РПС: ETC - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 11,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSEQ",
#           "board_title": "РПС: Акции - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 12,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSES",
#           "board_title": "РПС: А2-Акции и паи - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 15,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSNL",
#           "board_title": "РПС: Б-Акции и паи - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 32,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSLV",
#           "board_title": "РПС: В-Акции и ДР - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 118,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSDE",
#           "board_title": "РПС: Акции Д - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 1
#         },
#         {
#           "id": 31,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSLI",
#           "board_title": "РПС: И-Акции - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 14,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSNE",
#           "board_title": "РПС: Акции, паи и ДР внесписочные - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 17,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSOB",
#           "board_title": "РПС: Облигации - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 18,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSOS",
#           "board_title": "РПС: А2-Облигации - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 16,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSNO",
#           "board_title": "РПС: Б-Облигации - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 33,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSOV",
#           "board_title": "РПС: В-Облигации - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 92,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSDB",
#           "board_title": "РПС: Облигации Д - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 13,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSNB",
#           "board_title": "РПС: Облигации внесписочные - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 89,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSUS",
#           "board_title": "РПС: Облигации в ин.валюте - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 236,
#           "board_group_id": 8,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSYO",
#           "board_title": "РПС: Облигации (CNY) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 1
#         },
#         {
#           "id": 30,
#           "board_group_id": 106,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSEU",
#           "board_title": "РПС: Облигации (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 160,
#           "board_group_id": 106,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSEO",
#           "board_title": "РПС: Облигации (EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 235,
#           "board_group_id": 106,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSGO",
#           "board_title": "РПС: Облигации (GBP) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 98,
#           "board_group_id": 107,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSAU",
#           "board_title": "Размещение - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 99,
#           "board_group_id": 107,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PAUS",
#           "board_title": "Размещение (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 159,
#           "board_group_id": 107,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PAEU",
#           "board_title": "Размещение (EUR) - адрес.",
#           "is_traded": 0,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 169,
#           "board_group_id": 107,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PAGB",
#           "board_title": "Размещение (GBP) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 237,
#           "board_group_id": 107,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PACY",
#           "board_title": "Размещение (CNY) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 120,
#           "board_group_id": 108,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSBB",
#           "board_title": "Выкуп - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 278,
#           "board_group_id": 121,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSBE",
#           "board_title": "Выкуп (EUR) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 282,
#           "board_group_id": 126,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "OTCB",
#           "board_title": "Анонимный РПС - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 353,
#           "board_group_id": 203,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "OTCU",
#           "board_title": "Анонимный РПС (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 355,
#           "board_group_id": 205,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "OTCE",
#           "board_title": "Анонимный РПС (EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 232,
#           "board_group_id": 73,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTOD",
#           "board_title": "РПС с ЦК: Облигации (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 230,
#           "board_group_id": 73,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTSD",
#           "board_title": "РПС с ЦК: Акции и ДР (USD) - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 231,
#           "board_group_id": 73,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTTD",
#           "board_title": "РПС с ЦК: ETF (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 277,
#           "board_group_id": 124,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSBU",
#           "board_title": "Выкуп (USD) - адрес.",
#           "is_traded": 1,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 316,
#           "board_group_id": 160,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSSE",
#           "board_title": "РПС: Акции и ДР (расч. в EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 317,
#           "board_group_id": 161,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSTE",
#           "board_title": "РПС: ETF (расч. в EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 318,
#           "board_group_id": 162,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTSE",
#           "board_title": "РПС с ЦК: Акции и ДР (расч. в EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 319,
#           "board_group_id": 163,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PTTE",
#           "board_title": "РПС с ЦК: ETF (расч. в EUR) - адрес.",
#           "is_traded": 1,
#           "has_candles": 1,
#           "is_primary": 0
#         },
#         {
#           "id": 97,
#           "board_group_id": 32,
#           "engine_id": 1,
#           "market_id": 4,
#           "boardid": "PSCC",
#           "board_title": "РПС с ЦК - адрес.",
#           "is_traded": 0,
#           "has_candles": 0,
#           "is_primary": 0
#         },
#         {
#           "id": 44,
#           "board_group_id": 9,
#           "engine_id": 1,
#           "market_id": 5,
#           "boardid": "SNDX",
# ...
#           "is_hidden": 0
#         }
#       ]
#     ],
#     "securitycollections": [
#       {
#         "metadata": {
#           "id": {
#             "type": "int32"
#           },
#           "name": {
#             "type": "string",
#             "bytes": 96,
#             "max_size": 0
#           },
#           "title": {
#             "type": "string",
#             "bytes": 765,
#             "max_size": 0
#           },
#           "security_group_id": {
#             "type": "int32"
#           }
#         }
#       },
#       [
#         {
#           "id": 72,
#           "name": "stock_index_all",
#           "title": "Все индексы",
#           "security_group_id": 12
#         },
#         {
#           "id": 213,
#           "name": "stock_index_shares",
#           "title": "Основные индексы акций",
#           "security_group_id": 12
#         },
#         {
#           "id": 210,
#           "name": "stock_index_shares_sectoral",
#           "title": "Отраслевые индексы акций",
#           "security_group_id": 12
#         },
#         {
#           "id": 249,
#           "name": "stock_index_total_return",
#           "title": "Индексы акций полной доходности",
#           "security_group_id": 12
#         },
#         {
#           "id": 211,
#           "name": "stock_index_shares_thematic",
#           "title": "Тематические индексы акций",
#           "security_group_id": 12
#         },
#         {
#           "id": 207,
#           "name": "stock_index_bonds",
#           "title": "Основные индексы облигаций",
#           "security_group_id": 12
#         },
#         {
#           "id": 214,
#           "name": "stock_index_bonds_state",
#           "title": "Индексы государственных облигаций",
#           "security_group_id": 12
#         },
#         {
#           "id": 208,
#           "name": "stock_index_bonds_corporate",
#           "title": "Индексы корпоративных облигаций",
#           "security_group_id": 12
#         },
#         {
#           "id": 212,
#           "name": "stock_index_bonds_municipal",
#           "title": "Индексы муниципальных облигаций",
#           "security_group_id": 12
#         },
#         {
#           "id": 209,
#           "name": "stock_index_bonds_retiring",
#           "title": "Индексы активов пенсионных накоплений",
#           "security_group_id": 12
#         },
#         {
#           "id": 215,
#           "name": "stock_index_volatility",
#           "title": "Российские индексы волатильности",
#           "security_group_id": 12
#         },
#         {
#           "id": 259,
#           "name": "stock_index_inav",
#           "title": "INAV",
#           "security_group_id": 12
#         },
#         {
#           "id": 115,
#           "name": "stock_index_repo",
#           "title": "Индикаторы ставок РЕПО",
#           "security_group_id": 12
#         },
#         {
#           "id": 295,
#           "name": "stock_index_mmix",
#           "title": "Money market index",
#           "security_group_id": 12
#         },
#         {
#           "id": 229,
#           "name": "stock_index_quotationlist_bond",
#           "title": "Облигационные индексы котировальных листов",
#           "security_group_id": 12
#         },
#         {
#           "id": 3,
#           "name": "stock_shares_all",
#           "title": "Все акции",
#           "security_group_id": 4
#         },
#         {
#           "id": 160,
#           "name": "stock_shares_one",
#           "title": "Уровень 1",
#           "security_group_id": 4
#         },
#         {
#           "id": 161,
#           "name": "stock_shares_two",
#           "title": "Уровень 2",
#           "security_group_id": 4
#         },
#         {
#           "id": 162,
#           "name": "stock_shares_three",
#           "title": "Уровень 3",
#           "security_group_id": 4
#         },
#         {
#           "id": 7,
#           "name": "stock_bonds_all",
#           "title": "Все",
#           "security_group_id": 3
#         },
#         {
#           "id": 163,
#           "name": "stock_bonds_one",
#           "title": "Все уровень 1",
#           "security_group_id": 3
#         },
#         {
#           "id": 164,
#           "name": "stock_bonds_two",
#           "title": "Все уровень 2",
#           "security_group_id": 3
#         },
#         {
#           "id": 165,
#           "name": "stock_bonds_three",
#           "title": "Все уровень 3",
#           "security_group_id": 3
#         },
#         {
#           "id": 189,
#           "name": "stock_bonds_corp_all",
#           "title": "Все корпоративные",
#           "security_group_id": 3
#         },
#         {
#           "id": 202,
#           "name": "stock_bonds_corp_one",
#           "title": "Корпоративные уровень 1",
#           "security_group_id": 3
#         },
#         {
#           "id": 194,
#           "name": "stock_bonds_corp_two",
#           "title": "Корпоративные уровень 2",
#           "security_group_id": 3
#         },
#         {
#           "id": 188,
#           "name": "stock_bonds_corp_three",
#           "title": "Корпоративные уровень 3",
#           "security_group_id": 3
#         },
#         {
#           "id": 200,
#           "name": "stock_bonds_exchange_all",
#           "title": "Все биржевые",
#           "security_group_id": 3
#         },
#         {
#           "id": 185,
#           "name": "stock_exchange_corp_one",
#           "title": "Биржевые уровень 1",
#           "security_group_id": 3
#         },
#         {
#           "id": 195,
#           "name": "stock_bonds_exchange_two",
#           "title": "Биржевые уровень 2",
#           "security_group_id": 3
#         },
#         {
#           "id": 190,
#           "name": "stock_bonds_exchange_three",
#           "title": "Биржевые уровень 3",
#           "security_group_id": 3
#         },
#         {
#           "id": 205,
#           "name": "stock_bonds_municipal_all",
#           "title": "Все муниципальные",
#           "security_group_id": 3
#         },
#         {
#           "id": 201,
#           "name": "stock_bonds_municipal_one",
#           "title": "Муниципальные уровень 1",
#           "security_group_id": 3
#         },
#         {
#           "id": 191,
#           "name": "stock_bonds_municipal_two",
#           "title": "Муниципальные уровень 2",
#           "security_group_id": 3
#         },
#         {
#           "id": 203,
#           "name": "stock_bonds_municipal_three",
#           "title": "Муниципальные уровень 3",
#           "security_group_id": 3
#         },
#         {
#           "id": 198,
#           "name": "stock_bonds_subfederal_all",
#           "title": "Все субъектов РФ",
#           "security_group_id": 3
#         },
#         {
#           "id": 206,
#           "name": "stock_bonds_subfederal_one",
#           "title": "Субъектов РФ уровень 1",
#           "security_group_id": 3
#         },
#         {
#           "id": 204,
#           "name": "stock_bonds_subfederal_two",
#           "title": "Субъектов РФ уровень 2",
#           "security_group_id": 3
#         },
#         {
#           "id": 192,
#           "name": "stock_bonds_subfederal_three",
#           "title": "Субъектов РФ уровень 3",
#           "security_group_id": 3
#         },
#         {
#           "id": 186,
#           "name": "stock_bonds_ofz_all",
#           "title": "Все ОФЗ",
#           "security_group_id": 3
#         },
#         {
#           "id": 193,
#           "name": "stock_bonds_cb_all",
#           "title": "Все Банка России",
#           "security_group_id": 3
#         },
#         {
#           "id": 197,
#           "name": "stock_bonds_ifi_all",
#           "title": "Все иностранных эмитентов",
#           "security_group_id": 3
#         },
#         {
#           "id": 199,
#           "name": "stock_bonds_ifi_one",
#           "title": "Иностранных эмитентов уровень 1",
#           "security_group_id": 3
#         },
#         {
#           "id": 187,
#           "name": "stock_bonds_ifi_two",
#           "title": "Иностранных эмитентов уровень 2",
#           "security_group_id": 3
#         },
#         {
#           "id": 196,
#           "name": "stock_bonds_ifi_three",
#           "title": "Иностранных эмитентов уровень 3",
#           "security_group_id": 3
#         },
#         {
#           "id": 177,
#           "name": "currency_selt_all_spot",
#           "title": "Все валюты СПОТ",
#           "security_group_id": 9
#         },
#         {
#           "id": 170,
#           "name": "currency_selt_all_swap",
#           "title": "Все валюты СВОП",
#           "security_group_id": 9
#         },
#         {
#           "id": 173,
#           "name": "currency_selt_usd_spot",
#           "title": "USD/RUB СПОТ",
#           "security_group_id": 9
#         },
#         {
#           "id": 174,
#           "name": "currency_selt_usd_swap",
#           "title": "USD/RUB СВОП",
#           "security_group_id": 9
#         },
#         {
#           "id": 172,
#           "name": "currency_selt_eur_spot",
#           "title": "EUR/RUB СПОТ",
#           "security_group_id": 9
#         },
#         {
#           "id": 179,
#           "name": "currency_selt_eur_swap",
#           "title": "EUR/RUB СВОП",
#           "security_group_id": 9
#         },
#         {
#           "id": 181,
#           "name": "currency_selt_cny_spot",
#           "title": "CNY/RUB СПОТ",
#           "security_group_id": 9
#         },
#         {
#           "id": 176,
#           "name": "currency_selt_cny_swap",
#           "title": "CNY/RUB СВОП",
#           "security_group_id": 9
#         },
#         {
#           "id": 178,
#           "name": "currency_selt_eurusd_spot",
#           "title": "EUR/USD СПОТ",
#           "security_group_id": 9
#         },
#         {
#           "id": 180,
#           "name": "currency_selt_eurusd_swap",
#           "title": "EUR/USD СВОП",
#           "security_group_id": 9
#         },
#         {
#           "id": 171,
#           "name": "currency_selt_other_spot",
#           "title": "Другие валюты СПОТ",
#           "security_group_id": 9
#         },
#         {
#           "id": 175,
#           "name": "currency_selt_other_swap",
#           "title": "Другие валюты СВОП",
#           "security_group_id": 9
#         },
#         {
#           "id": 227,
#           "name": "futures_forts_all",
#           "title": "Все фьючерсы",
#           "security_group_id": 10
#         },
#         {
#           "id": 226,
#           "name": "futures_forts_index",
#           "title": "Фьючерсы на индексы",
#           "security_group_id": 10
#         },
#         {
#           "id": 224,
#           "name": "futures_forts_shares",
#           "title": "Фьючерсы на акции",
#           "security_group_id": 10
#         },
#         {
#           "id": 225,
#           "name": "futures_forts_currency",
#           "title": "Фьючерсы на валюты",
#           "security_group_id": 10
#         },
#         {
#           "id": 228,
#           "name": "futures_forts_interest",
#           "title": "Фьючерсы на процентные ставки",
#           "security_group_id": 10
#         },
#         {
#           "id": 223,
#           "name": "futures_forts_commodity",
#           "title": "Фьючерсы на товарные контракты",
#           "security_group_id": 10
#         },
#         {
#           "id": 260,
#           "name": "futures_forts_ofz",
#           "title": "Фьючерсы на ОФЗ",
#           "security_group_id": 10
#         },
#         {
#           "id": 218,
#           "name": "futures_options_all",
#           "title": "Все опционы",
#           "security_group_id": 26
#         },
#         {
#           "id": 222,
#           "name": "futures_options_index",
#           "title": "Опционы ф. на индекс",
#           "security_group_id": 26
#         },
#         {
#           "id": 221,
#           "name": "futures_options_shares",
#           "title": "Опционы ф. на акции",
#           "security_group_id": 26
#         },
#         {
#           "id": 220,
#           "name": "futures_options_currency",
#           "title": "Опционы ф. на валюты",
#           "security_group_id": 26
#         },
#         {
#           "id": 219,
#           "name": "futures_options_commodity",
#           "title": "Опционы ф. на товарные контракты",
#           "security_group_id": 26
#         },
#         {
#           "id": 130,
#           "name": "stock_dr_all",
#           "title": "Все ДР",
#           "security_group_id": 18
#         },
#         {
#           "id": 60,
#           "name": "stock_eurobond_all",
#           "title": "Все",
#           "security_group_id": 6
#         },
#         {
#           "id": 184,
#           "name": "stock_eurobond_one",
#           "title": "Уровень 1",
#           "security_group_id": 6
#         },
#         {
#           "id": 182,
#           "name": "stock_eurobond_two",
#           "title": "Уровень 2",
#           "security_group_id": 6
#         },
#         {
#           "id": 183,
#           "name": "stock_eurobond_three",
#           "title": "Уровень 3",
#           "security_group_id": 6
#         },
#         {
#           "id": 59,
#           "name": "stock_ppif_all",
#           "title": "Все ПИФы",
#           "security_group_id": 5
#         },
#         {
#           "id": 166,
#           "name": "stock_ppif_one",
#           "title": "Уровень 1",
#           "security_group_id": 5
#         },
#         {
#           "id": 167,
#           "name": "stock_ppif_two",
#           "title": "Уровень 2",
#           "security_group_id": 5
#         },
#         {
#           "id": 168,
#           "name": "stock_ppif_three",
#           "title": "Уровень 3",
#           "security_group_id": 5
#         },
#         {
#           "id": 151,
#           "name": "stock_etf_all",
#           "title": "Все паи иностранных фондов",
#           "security_group_id": 20
#         },
#         {
#           "id": 216,
#           "name": "currency_metal_gold",
#           "title": "Золото",
#           "security_group_id": 24
#         },
#         {
#           "id": 217,
#           "name": "currency_metal_silver",
#           "title": "Серебро",
#           "security_group_id": 24
#         },
#         {
#           "id": 152,
#           "name": "stock_qnv_all",
#           "title": "Все квал. инвесторы",
#           "security_group_id": 21
#         },
#         {
#           "id": 230,
#           "name": "stock_gcc_all",
#           "title": "Клиринговые сертификаты участия",
#           "security_group_id": 27
#         },
#         {
#           "id": 258,
#           "name": "stock_deposit_all",
#           "title": "Депозиты с ЦК",
#           "security_group_id": 29
#         },
#         {
#           "id": 116,
#           "name": "currency_basket_all",
#           "title": "Бивалютная корзина",
#           "security_group_id": 17
#         },
#         {
#           "id": 286,
#           "name": "currency_futures_swap_all",
#           "title": "Все валюты поставочные СВОП КОНТРАКТЫ",
#           "security_group_id": 28
#         },
#         {
#           "id": 254,
#           "name": "currency_futures_delivery_all",
#           "title": "Все валюты поставочные ФЬЮЧЕРСЫ",
#           "security_group_id": 28
#         },
#         {
#           "id": 287,
#           "name": "currency_futures_swap_usd",
#           "title": "USD/RUB поставочный СВОП КОНТРАКТ",
#           "security_group_id": 28
#         },
#         {
#           "id": 252,
#           "name": "currency_futures_delivery_usd",
#           "title": "USD/RUB поставочный ФЬЮЧЕРС",
#           "security_group_id": 28
#         },
#         {
#           "id": 288,
#           "name": "currency_futures_swap_eur",
#           "title": "EUR/RUB поставочный СВОП КОНТРАКТ",
#           "security_group_id": 28
#         },
#         {
#           "id": 255,
#           "name": "currency_futures_delivery_eur",
#           "title": "EUR/RUB поставочный ФЬЮЧЕРС",
#           "security_group_id": 28
#         },
#         {
#           "id": 289,
#           "name": "currency_futures_swap_cny",
#           "title": "CNY/RUB поставочный СВОП КОНТРАКТ",
#           "security_group_id": 28
#         },
#         {
#           "id": 250,
#           "name": "currency_futures_delivery_cny",
#           "title": "CNY/RUB поставочный ФЬЮЧЕРС",
#           "security_group_id": 28
#         },
#         {
#           "id": 292,
#           "name": "currency_futures_swap_other",
#           "title": "Другие валюты поставочный СВОП КОНТРАКТ",
#           "security_group_id": 28
#         },
#         {
#           "id": 293,
#           "name": "currency_futures_delivery_others",
#           "title": "Другие валюты поставочный ФЬЮЧЕРС",
#           "security_group_id": 28
#         },
#         {
#           "id": 297,
#           "name": "currency_indices_all",
#           "title": "Все валютные фиксинги",
#           "security_group_id": 31
#         }
#       ]
#     ]
#   }
# ]

# %%
# Out:
# Cached http://iss.moex.com/iss/index.json
# 'http://iss.moex.com/iss/index.json'
