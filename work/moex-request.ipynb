# %%
import shelve
import time
from datetime import datetime

_cache = shelve.open("cache")
TIMEOUT = 86400 * 30
def is_expired(dt, limit_seconds = 86400*7):
    return (datetime.now() - datetime.fromisoformat(dt)).seconds > limit_seconds

def clear_cache():
    _cache.clear()
    _cache.sync()

def cache(fun):
    def to_url(*args, **kwargs):
        url = kwargs['url'] if 'url' in kwargs else args[0]
        params_dict = kwargs['params'] if 'params' in kwargs else args[1] if len(args) > 1 else dict()
        params = '&'.join([str(k) + '=' + str(v) for (k,v) in params_dict.items()])
        return url + "?" + params
        
    def wrapper(*args, **kwargs):
        url = to_url(*args, **kwargs)
        print("url: " + url)
        if (url not in _cache):
            print("Not cached " + url)
            result = fun(*args, **kwargs)
            _cache[url] = {
                'url': url,
                'timestamp': datetime.now().isoformat(),
                'result': result
            }
            _cache.sync()
            return result
        
        result = _cache[url]
        if(not is_expired(result['timestamp'], TIMEOUT)):
            print("Cached " + url)
            return result['result']
        
        print("Expired " + url)
        result = fun(*args, **kwargs)
        _cache[url] = {
            'url': url,
            'timestamp': datetime.now().isoformat(),
            'result': result
        }
        _cache.sync()
        return result
        
    return wrapper

# %%
# Create schema
import sqlite3
conn = sqlite3.connect('moex.db')
try:
    c = conn.cursor()
    c.execute(
        '''CREATE TABLE IF NOT EXISTS engines (
            id int, 
            name text, 
            title text
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS markets (
            id int, 
            trade_engine_id int,
            trade_engine_name text, 
            trade_engine_title text,
            market_name text,
            market_title text,
            market_id int,
            marketplace text
        )''')

    c.execute(
        '''CREATE TABLE IF NOT EXISTS boards (
            id int,
            board_group_id int,
            engine_id int,
            market_id int,
            boardid int,
            board_title text,
            is_traded int,
            has_candles int,
            is_primary int
        )''')

    c.execute(
        '''CREATE TABLE IF NOT EXISTS boardgroups (
            id int,
            trade_engine_id int,
            trade_engine_name text,
            trade_engine_title text,
            market_id int,
            market_name text,
            name text,
            title text,
            is_default int,
            board_group_id int,
            is_traded int
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS durations (
            interval int,
            duration int,
            days int,
            title text,
            hint text
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securitytypes (
            id int,
            trade_engine_id int,
            trade_engine_name text,
            trade_engine_title text,
            security_type_name text,
            security_type_title text
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securitygroups (
            id int,
            name text,
            title text,
            is_hidden int
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securitycollections (
            id int,
            name text,
            title text,
            security_group_id int
        )''')
    c.execute(
        '''CREATE TABLE IF NOT EXISTS securities (
            id int,
            secid text,
            shortname text,
            regnumber text,
            name text,
            isin text,
            is_traded int,
            emitent_id int,
            emitent_title text,
            emitent_inn text,
            emitent_okpo text,
            gosreg text,
            type text,
            "group" text,
            primary_boardid text,
            marketprice_boardid text
        )''')
finally:
    conn.close()

# %%
def fill_engines(engines):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM engines')
        conn.commit()
        for e in engines:
            conn.execute('insert into engines values (?,?,?)',(
                e['id'],
                e['name'],
                e['title']
            ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_markets(markets):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM markets')
        conn.commit()
        for e in markets:                        
            conn.execute('insert into markets values (?,?,?,?,?,?,?,?)',(
                e['id'],
                e['trade_engine_id'],
                e['trade_engine_name'],
                e['trade_engine_title'],
                e['market_name'],
                e['market_title'],
                e['market_id'],
                e['marketplace']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_boards(boards):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM boards')
        conn.commit()
        for e in boards:
            conn.execute('insert into boards values (?,?,?,?,?,?,?,?,?)',(
                e['id'],
                e['board_group_id'],
                e['engine_id'],
                e['market_id'],
                e['boardid'],
                e['board_title'],
                e['is_traded'],
                e['has_candles'],
                e['is_primary']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_boardgroups(boardgroups):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM boardgroups')
        conn.commit()
        for e in boardgroups:
            conn.execute('insert into boardgroups values (?,?,?,?,?,?,?,?,?,?,?)',(
                e['id'],
                e['trade_engine_id'],
                e['trade_engine_name'],
                e['trade_engine_title'],
                e['market_id'],
                e['market_name'],
                e['name'],
                e['title'],
                e['is_default'],
                e['board_group_id'],
                e['is_traded']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_durations(durations):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM durations')
        conn.commit()
        for e in durations:
            conn.execute('insert into durations values (?,?,?,?,?)',(
                e['interval'],
                e['duration'],
                e['days'],
                e['title'],
                e['hint']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securitytypes(securitytypes):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securitytypes')
        conn.commit()
        for e in securitytypes:
            conn.execute('insert into securitytypes values (?,?,?,?,?,?)',(
                e['id'],
                e['trade_engine_id'],
                e['trade_engine_name'],
                e['trade_engine_title'],
                e['security_type_name'],
                e['security_type_title']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securitygroups(securitygroups):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securitygroups')
        conn.commit()
        for e in securitygroups:
            conn.execute('insert into securitygroups values (?,?,?,?)',(
                e['id'],
                e['name'],
                e['title'],
                e['is_hidden']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securitycollections(securitycollections):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securitycollections')
        conn.commit()
        for e in securitycollections:
            conn.execute('insert into securitycollections values (?,?,?,?)',(
                e['id'],
                e['name'],
                e['title'],
                e['security_group_id']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
def fill_securities(securities):
    conn = sqlite3.connect('moex.db')
    try:
        conn.execute('DELETE FROM securities')
    finally:
        conn.close()

    for batch in securities:
        b = batch[1]['securities'][1]
        fill_security_batch(b)
        print('Inserted ', len(b))

def fill_security_batch(securities):
    conn = sqlite3.connect('moex.db')
    try:
        for e in securities:
            conn.execute('insert into securities values (?,?,?,?,?, ?,?,?,?,?, ?,?,?,?,?, ?)',(
                e['id'],
                e['secid'],
                e['shortname'],
                e['regnumber'],
                e['name'],
                e['isin'],
                e['is_traded'],
                e['emitent_id'],
                e['emitent_title'],
                e['emitent_inn'],
                e['emitent_okpo'],
                e['gosreg'],
                e['type'],
                e['group'],
                e['primary_boardid'],
                e['marketprice_boardid']
             ))
        conn.commit()
    finally:
        conn.close()

# %%
m = moex_markets()
print('engines ', m[1]['engines'][1][0])
fill_engines(m[1]['engines'][1])

print('markets ', m[1]['markets'][1][0])
fill_markets(m[1]['markets'][1])

print('boards ', m[1]['boards'][1][0])
fill_boards(m[1]['boards'][1])

print('boardgroups ', m[1]['boardgroups'][1][0])
fill_boardgroups(m[1]['boardgroups'][1])

print('durations ', m[1]['durations'][1][0])
fill_durations(m[1]['durations'][1])

print('securitytypes ', m[1]['securitytypes'][1][0])
fill_securitytypes(m[1]['securitytypes'][1])

print('securitygroups ', m[1]['securitygroups'][1][0])
fill_securitygroups(m[1]['securitygroups'][1])

print('securitycollections ', m[1]['securitycollections'][1][0])
fill_securitycollections(m[1]['securitycollections'][1])
# Out:
# url: http://iss.moex.com/iss/index.json?iss.json=extended
# Cached http://iss.moex.com/iss/index.json?iss.json=extended
# engines  {'id': 1, 'name': 'stock', 'title': 'Фондовый рынок и рынок депозитов'}
# markets  {'id': 5, 'trade_engine_id': 1, 'trade_engine_name': 'stock', 'trade_engine_title': 'Фондовый рынок и рынок депозитов', 'market_name': 'index', 'market_title': 'Индексы фондового рынка', 'market_id': 5, 'marketplace': 'INDICES'}
# boards  {'id': 260, 'board_group_id': 99, 'engine_id': 1, 'market_id': 1, 'boardid': 'EQTD', 'board_title': 'Т0 ETF (USD) - безадрес.', 'is_traded': 1, 'has_candles': 1, 'is_primary': 0}
# boardgroups  {'id': 9, 'trade_engine_id': 1, 'trade_engine_name': 'stock', 'trade_engine_title': 'Фондовый рынок и рынок депозитов', 'market_id': 5, 'market_name': 'index', 'name': 'stock_index', 'title': 'Индексы', 'is_default': 1, 'board_group_id': 9, 'is_traded': 1}
# durations  {'interval': 1, 'duration': 60, 'days': None, 'title': 'минута', 'hint': '1м'}
# securitytypes  {'id': 3, 'trade_engine_id': 1, 'trade_engine_name': 'stock', 'trade_engine_title': 'Фондовый рынок и рынок депозитов', 'security_type_name': 'common_share', 'security_type_title': 'Акция обыкновенная'}
# securitygroups  {'id': 12, 'name': 'stock_index', 'title': 'Индексы', 'is_hidden': 0}
# securitycollections  {'id': 72, 'name': 'stock_index_all', 'title': 'Все индексы', 'security_group_id': 12}

# %%
securites = moex_securities()
fill_securities(securites)
# Out:
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=0
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=0
# From 0took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=100
# From 100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=200
# From 200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=300
# From 300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=400
# From 400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=500
# From 500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=600
# From 600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=700
# From 700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=800
# From 800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=900
# From 900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1000
# From 1000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1100
# From 1100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1200
# From 1200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1300
# From 1300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1400
# From 1400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1500
# From 1500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1600
# From 1600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1700
# From 1700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1800
# From 1800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1900
# From 1900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2000
# From 2000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2100
# From 2100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2200
# From 2200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2300
# From 2300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2400
# From 2400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2500
# From 2500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2600
# From 2600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2700
# From 2700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2800
# From 2800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2900
# From 2900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3000
# From 3000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3100
# From 3100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3200
# From 3200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3300
# From 3300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3400
# From 3400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3500
# From 3500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3600
# From 3600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3700
# From 3700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3800
# From 3800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3900
# From 3900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4000
# From 4000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4100
# From 4100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4200
# From 4200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4300
# From 4300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4400
# From 4400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4500
# From 4500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4600
# From 4600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4700
# From 4700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4800
# From 4800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4900
# From 4900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5000
# From 5000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5100
# From 5100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5200
# From 5200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5300
# From 5300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5400
# From 5400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5500
# From 5500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5600
# From 5600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5700
# From 5700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5800
# From 5800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5900
# From 5900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6000
# From 6000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6100
# From 6100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6200
# From 6200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6300
# From 6300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6400
# From 6400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6500
# From 6500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6600
# From 6600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6700
# From 6700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6800
# From 6800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6900
# From 6900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7000
# From 7000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7100
# From 7100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7200
# From 7200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7300
# From 7300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7400
# From 7400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7500
# From 7500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7600
# From 7600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7700
# From 7700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7800
# From 7800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7900
# From 7900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8000
# From 8000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8100
# From 8100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8200
# From 8200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8300
# From 8300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8400
# From 8400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8500
# From 8500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8600
# From 8600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8700
# From 8700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8800
# From 8800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8900
# From 8900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9000
# From 9000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9100
# From 9100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9200
# From 9200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9300
# From 9300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9400
# From 9400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9500
# From 9500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9600
# From 9600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9700
# From 9700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9800
# From 9800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9900
# From 9900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10000
# From 10000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10100
# From 10100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10200
# From 10200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10300
# From 10300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10400
# From 10400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10500
# From 10500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10600
# From 10600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10700
# From 10700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10800
# From 10800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10900
# From 10900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11000
# From 11000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11100
# From 11100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11200
# From 11200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11300
# From 11300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11400
# From 11400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11500
# From 11500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11600
# From 11600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11700
# From 11700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11800
# From 11800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11900
# From 11900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12000
# From 12000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12100
# From 12100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12200
# From 12200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12300
# From 12300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12400
# From 12400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12500
# From 12500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12600
# From 12600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12700
# From 12700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12800
# From 12800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12900
# From 12900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13000
# From 13000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13100
# From 13100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13200
# From 13200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13300
# From 13300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13400
# From 13400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13500
# From 13500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13600
# From 13600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13700
# From 13700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13800
# From 13800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13900
# From 13900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14000
# From 14000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14100
# From 14100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14200
# From 14200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14300
# From 14300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14400
# From 14400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14500
# From 14500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14600
# From 14600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14700
# From 14700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14800
# From 14800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14900
# From 14900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15000
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15000
# From 15000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15100
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15100
# From 15100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15200
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15200
# From 15200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15300
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15300
# From 15300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15400
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15400
# From 15400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15500
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15500
# From 15500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15600
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15600
# From 15600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15700
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15700
# From 15700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15800
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15800
# From 15800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15900
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15900
# From 15900took 38
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15938
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15938
# From 15938took 0
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  100
# Inserted  38
# Inserted  0

# %%
import requests
@cache
def get(url, params = None):
    return requests.get(url, params).json()

# %%
clear_cache()

# %%
# For testing
@cache
def do(url, params = {}):
    return params
print(do(url="123", params={"a": 1, "b": 2}))
print(do(url="456", params={"a": 1, "b": 2}))
print(do("123", {"a": 1, "b": 2}))
time.sleep(2)
print(do(url="123"))
# Out:
# url: 123?a=1&b=2
# Cached 123?a=1&b=2
# {'url': '123?a=1&b=2', 'timestamp': '2020-05-13T19:23:09.441742', 'result': {'a': 1, 'b': 2}}
# url: 456?a=1&b=2
# Cached 456?a=1&b=2
# {'url': '456?a=1&b=2', 'timestamp': '2020-05-13T19:23:09.457036', 'result': {'a': 1, 'b': 2}}
# url: 123?a=1&b=2
# Cached 123?a=1&b=2
# {'url': '123?a=1&b=2', 'timestamp': '2020-05-13T19:23:09.441742', 'result': {'a': 1, 'b': 2}}
# url: 123?
# Cached 123?
# {'url': '123?', 'timestamp': '2020-05-13T19:24:18.867112', 'result': {}}

# %%
def moex_markets():
    return get('http://iss.moex.com/iss/index.json', {'iss.json': 'extended'})

# %%
def moex_securities():
    start = 0
    limit = 100
    count = 1 # initial truish value
    results = []
    while count > 0:
        batch = get('http://iss.moex.com/iss/securities.json', {'iss.json': 'extended', 'limit': limit, 'start':start})
        results.append(batch)
        count = len(batch[1]['securities'][1])
        print ("From " + str(start) + "took " + str(count))
        start += count
    return results

# %%
x = moex_securities()
# Out:
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=0
# Cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=0
# From 0took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=100
# From 100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=200
# From 200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=300
# From 300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=400
# From 400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=500
# From 500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=600
# From 600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=700
# From 700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=800
# From 800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=900
# From 900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1000
# From 1000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1100
# From 1100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1200
# From 1200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1300
# From 1300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1400
# From 1400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1500
# From 1500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1600
# From 1600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1700
# From 1700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1800
# From 1800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=1900
# From 1900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2000
# From 2000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2100
# From 2100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2200
# From 2200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2300
# From 2300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2400
# From 2400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2500
# From 2500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2600
# From 2600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2700
# From 2700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2800
# From 2800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=2900
# From 2900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3000
# From 3000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3100
# From 3100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3200
# From 3200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3300
# From 3300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3400
# From 3400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3500
# From 3500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3600
# From 3600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3700
# From 3700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3800
# From 3800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=3900
# From 3900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4000
# From 4000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4100
# From 4100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4200
# From 4200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4300
# From 4300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4400
# From 4400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4500
# From 4500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4600
# From 4600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4700
# From 4700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4800
# From 4800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=4900
# From 4900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5000
# From 5000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5100
# From 5100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5200
# From 5200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5300
# From 5300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5400
# From 5400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5500
# From 5500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5600
# From 5600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5700
# From 5700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5800
# From 5800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=5900
# From 5900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6000
# From 6000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6100
# From 6100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6200
# From 6200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6300
# From 6300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6400
# From 6400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6500
# From 6500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6600
# From 6600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6700
# From 6700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6800
# From 6800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=6900
# From 6900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7000
# From 7000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7100
# From 7100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7200
# From 7200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7300
# From 7300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7400
# From 7400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7500
# From 7500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7600
# From 7600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7700
# From 7700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7800
# From 7800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=7900
# From 7900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8000
# From 8000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8100
# From 8100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8200
# From 8200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8300
# From 8300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8400
# From 8400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8500
# From 8500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8600
# From 8600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8700
# From 8700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8800
# From 8800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=8900
# From 8900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9000
# From 9000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9100
# From 9100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9200
# From 9200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9300
# From 9300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9400
# From 9400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9500
# From 9500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9600
# From 9600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9700
# From 9700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9800
# From 9800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=9900
# From 9900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10000
# From 10000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10100
# From 10100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10200
# From 10200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10300
# From 10300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10400
# From 10400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10500
# From 10500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10600
# From 10600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10700
# From 10700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10800
# From 10800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=10900
# From 10900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11000
# From 11000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11100
# From 11100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11200
# From 11200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11300
# From 11300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11400
# From 11400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11500
# From 11500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11600
# From 11600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11700
# From 11700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11800
# From 11800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=11900
# From 11900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12000
# From 12000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12100
# From 12100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12200
# From 12200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12300
# From 12300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12400
# From 12400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12500
# From 12500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12600
# From 12600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12700
# From 12700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12800
# From 12800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=12900
# From 12900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13000
# From 13000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13100
# From 13100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13200
# From 13200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13300
# From 13300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13400
# From 13400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13500
# From 13500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13600
# From 13600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13700
# From 13700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13800
# From 13800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=13900
# From 13900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14000
# From 14000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14100
# From 14100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14200
# From 14200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14300
# From 14300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14400
# From 14400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14500
# From 14500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14600
# From 14600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14700
# From 14700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14800
# From 14800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=14900
# From 14900took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15000
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15000
# From 15000took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15100
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15100
# From 15100took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15200
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15200
# From 15200took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15300
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15300
# From 15300took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15400
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15400
# From 15400took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15500
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15500
# From 15500took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15600
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15600
# From 15600took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15700
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15700
# From 15700took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15800
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15800
# From 15800took 100
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15900
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15900
# From 15900took 38
# url: http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15938
# Not cached http://iss.moex.com/iss/securities.json?iss.json=extended&limit=100&start=15938
# From 15938took 0

# %%
x[0]
# Out:
# [{'charsetinfo': {'name': 'utf-8'}},
#  {'securities': [{'metadata': {'id': {'type': 'int32'},
#      'secid': {'type': 'string', 'bytes': 36, 'max_size': 0},
#      'shortname': {'type': 'string', 'bytes': 189, 'max_size': 0},
#      'regnumber': {'type': 'string', 'bytes': 189, 'max_size': 0},
#      'name': {'type': 'string', 'bytes': 765, 'max_size': 0},
#      'isin': {'type': 'string', 'bytes': 765, 'max_size': 0},
#      'is_traded': {'type': 'int32'},
#      'emitent_id': {'type': 'int32'},
#      'emitent_title': {'type': 'string', 'bytes': 765, 'max_size': 0},
#      'emitent_inn': {'type': 'string', 'bytes': 30, 'max_size': 0},
#      'emitent_okpo': {'type': 'string', 'bytes': 24, 'max_size': 0},
#      'gosreg': {'type': 'string', 'bytes': 189, 'max_size': 0},
#      'type': {'type': 'string', 'bytes': 93, 'max_size': 0},
#      'group': {'type': 'string', 'bytes': 93, 'max_size': 0},
#      'primary_boardid': {'type': 'string', 'bytes': 12, 'max_size': 0},
#      'marketprice_boardid': {'type': 'string', 'bytes': 12, 'max_size': 0}}},
#    [{'id': 154676,
#      'secid': 'AAPL',
#      'shortname': 'Apple',
#      'regnumber': None,
#      'name': 'Apple Inc.',
#      'isin': 'US0378331005',
#      'is_traded': 1,
#      'emitent_id': 1281003,
#      'emitent_title': 'Apple Inc',
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'EQRD',
#      'marketprice_boardid': None},
#     {'id': 12441,
#      'secid': 'ABRD',
#      'shortname': 'АбрауДюрсо',
#      'regnumber': '1-02-12500-A',
#      'name': 'Абрау-Дюрсо ПАО ао',
#      'isin': 'RU000A0JS5T7',
#      'is_traded': 1,
#      'emitent_id': 2556,
#      'emitent_title': 'Публичное акционерное общество "Абрау – Дюрсо"',
#      'emitent_inn': '7727620673',
#      'emitent_okpo': '81521198',
#      'gosreg': '1-02-12500-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 131568,
#      'secid': 'ACKO',
#      'shortname': 'АСКО ао',
#      'regnumber': '1-01-52065-Z',
#      'name': 'АСКО-СТРАХОВАНИЕ ПАО ао',
#      'isin': 'RU000A0JXS91',
#      'is_traded': 1,
#      'emitent_id': 1098705,
#      'emitent_title': 'Публичное акционерное общество "АСКО-СТРАХОВАНИЕ"',
#      'emitent_inn': '7453297458',
#      'emitent_okpo': '31212003',
#      'gosreg': '1-01-52065-Z',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQDE',
#      'marketprice_boardid': 'TQDE'},
#     {'id': 85909,
#      'secid': 'acru',
#      'shortname': 'ОАО АК "Рубин"',
#      'regnumber': '1-03-01692-A',
#      'name': 'Открытое акционерное общество "Авиационная корпорация "Рубин"',
#      'isin': 'RU000A0JRM20',
#      'is_traded': 1,
#      'emitent_id': 486957,
#      'emitent_title': 'публичное акционерное общество "Авиационная корпорация "Рубин"',
#      'emitent_inn': '5001000034',
#      'emitent_okpo': None,
#      'gosreg': '1-03-01692-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 2699,
#      'secid': 'AFKS',
#      'shortname': 'Система ао',
#      'regnumber': '1-05-01669-A',
#      'name': 'АФК "Система" ПАО ао',
#      'isin': 'RU000A0DQZE3',
#      'is_traded': 1,
#      'emitent_id': 2046,
#      'emitent_title': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "АКЦИОНЕРНАЯ ФИНАНСОВАЯ КОРПОРАЦИЯ "СИСТЕМА"',
#      'emitent_inn': '7703104630',
#      'emitent_okpo': '27987276',
#      'gosreg': '1-05-01669-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 2700,
#      'secid': 'AFLT',
#      'shortname': 'Аэрофлот',
#      'regnumber': '1-01-00010-A',
#      'name': 'Аэрофлот-росс.авиалин(ПАО)ао',
#      'isin': 'RU0009062285',
#      'is_traded': 1,
#      'emitent_id': 1300,
#      'emitent_title': 'Публичное акционерное общество "Аэрофлот – российские авиалинии"',
#      'emitent_inn': '7712040126',
#      'emitent_okpo': '29063984',
#      'gosreg': '1-01-00010-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 212232577,
#      'secid': 'AFM0',
#      'shortname': 'AFLT-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт AFLT-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': 1300,
#      'emitent_title': 'Публичное акционерное общество "Аэрофлот – российские авиалинии"',
#      'emitent_inn': '7712040126',
#      'emitent_okpo': '29063984',
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 85916,
#      'secid': 'afmc',
#      'shortname': 'АО "Агрофирма Мценская"',
#      'regnumber': '1-01-40534-A',
#      'name': 'Акционерное общество "Агрофирма Мценская"',
#      'isin': 'RU000A0JRAA9',
#      'is_traded': 1,
#      'emitent_id': 486951,
#      'emitent_title': 'Акционерное общество "Агрофирма Мценская"',
#      'emitent_inn': '5717060059',
#      'emitent_okpo': None,
#      'gosreg': '1-01-40534-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 292308367,
#      'secid': 'AFU0',
#      'shortname': 'AFLT-9.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт AFLT-9.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': 1300,
#      'emitent_title': 'Публичное акционерное общество "Аэрофлот – российские авиалинии"',
#      'emitent_inn': '7712040126',
#      'emitent_okpo': '29063984',
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 76079,
#      'secid': 'AGRO',
#      'shortname': 'AGRO-гдр',
#      'regnumber': None,
#      'name': 'ГДР ROS AGRO PLC ORD SHS',
#      'isin': 'US7496552057',
#      'is_traded': 1,
#      'emitent_id': 11660,
#      'emitent_title': 'Bank of New York Mellon Corporation (Глобальные депозитарные расписки на акции ROS AGRO PLC)',
#      'emitent_inn': '0000003817',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'depositary_receipt',
#      'group': 'stock_dr',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 262162603,
#      'secid': 'AKCBI',
#      'shortname': 'iАльфа-Капитал Облигации',
#      'regnumber': None,
#      'name': 'Индикатор «Альфа-Капитал. Облигации»',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'RTSI',
#      'marketprice_boardid': None},
#     {'id': 127728269,
#      'secid': 'AKEU',
#      'shortname': 'AKEU ETF',
#      'regnumber': '3805',
#      'name': 'БПИФ АЛЬФА_КАП ЕВРОПА 600',
#      'isin': 'RU000A100Q43',
#      'is_traded': 1,
#      'emitent_id': 2143,
#      'emitent_title': 'Общество с ограниченной ответственностью "Управляющая компания "Альфа-Капитал"',
#      'emitent_inn': '7728142469',
#      'emitent_okpo': '45022341',
#      'gosreg': '3805',
#      'type': 'exchange_ppif',
#      'group': 'stock_ppif',
#      'primary_boardid': 'TQTE',
#      'marketprice_boardid': 'TQTE'},
#     {'id': 126595747,
#      'secid': 'AKEUA',
#      'shortname': 'iNAV Альфа-Капитал ЕВРОПА 600',
#      'regnumber': None,
#      'name': 'Расчетная цена одного пая Биржевого ПИФа «ЕВРОПА 600»',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'INAV',
#      'marketprice_boardid': None},
#     {'id': 7603801,
#      'secid': 'AKNX',
#      'shortname': 'AKNX ETF',
#      'regnumber': '3591',
#      'name': 'БПИФ АЛЬФА_КАП ТЕХНОЛОГИИ 100',
#      'isin': 'RU000A0ZZTQ4',
#      'is_traded': 1,
#      'emitent_id': 2143,
#      'emitent_title': 'Общество с ограниченной ответственностью "Управляющая компания "Альфа-Капитал"',
#      'emitent_inn': '7728142469',
#      'emitent_okpo': '45022341',
#      'gosreg': '3591',
#      'type': 'exchange_ppif',
#      'group': 'stock_ppif',
#      'primary_boardid': 'TQTD',
#      'marketprice_boardid': 'TQTD'},
#     {'id': 5292334,
#      'secid': 'AKNXA',
#      'shortname': 'iNAV Технологии 100',
#      'regnumber': None,
#      'name': 'Расчетная цена одного пая Биржевого ПИФа «ТЕХНОЛОГИИ 100»',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'INAV',
#      'marketprice_boardid': None},
#     {'id': 2702,
#      'secid': 'AKRN',
#      'shortname': 'Акрон',
#      'regnumber': '1-03-00207-A',
#      'name': 'Акрон ПАО ао',
#      'isin': 'RU0009028674',
#      'is_traded': 1,
#      'emitent_id': 1418,
#      'emitent_title': 'Публичное акционерное общество "Акрон"',
#      'emitent_inn': '5321029508',
#      'emitent_okpo': '00203789',
#      'gosreg': '1-03-00207-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 48109977,
#      'secid': 'AKSP',
#      'shortname': 'AKSP ETF',
#      'regnumber': '3691',
#      'name': 'БПИФ АЛЬФА_КАП Эс энд Пи 500',
#      'isin': 'RU000A1006V3',
#      'is_traded': 1,
#      'emitent_id': 2143,
#      'emitent_title': 'Общество с ограниченной ответственностью "Управляющая компания "Альфа-Капитал"',
#      'emitent_inn': '7728142469',
#      'emitent_okpo': '45022341',
#      'gosreg': '3691',
#      'type': 'exchange_ppif',
#      'group': 'stock_ppif',
#      'primary_boardid': 'TQTD',
#      'marketprice_boardid': 'TQTD'},
#     {'id': 48107417,
#      'secid': 'AKSPA',
#      'shortname': 'iNAV Альфа - Капитал Эс энд Пи 500',
#      'regnumber': None,
#      'name': 'Расчетная цена одного пая Биржевого ПИФа «Альфа - Капитал Эс энд Пи 500»',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'INAV',
#      'marketprice_boardid': None},
#     {'id': 13080,
#      'secid': 'ALBK',
#      'shortname': 'БестЭфБ ао',
#      'regnumber': '10400435B',
#      'name': 'Бест Эффортс Банк ПАО ао',
#      'isin': 'RU000A0JS2M9',
#      'is_traded': 1,
#      'emitent_id': 2706,
#      'emitent_title': 'Публичное акционерное общество "Бест Эффортс Банк"',
#      'emitent_inn': '7831000034',
#      'emitent_okpo': '09801026',
#      'gosreg': '10400435B',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 212232579,
#      'secid': 'ALM0',
#      'shortname': 'ALRS-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALRS-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': 1246,
#      'emitent_title': 'Акционерная компания "АЛРОСА" (публичное акционерное общество)',
#      'emitent_inn': '1433000147',
#      'emitent_okpo': '23308410',
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 8112,
#      'secid': 'ALNU',
#      'shortname': 'АЛРОСА-Нюр',
#      'regnumber': '1-01-20179-F',
#      'name': 'АЛРОСА-Нюрба ПАО ао',
#      'isin': 'RU000A0JP468',
#      'is_traded': 1,
#      'emitent_id': 2466,
#      'emitent_title': 'Публичное акционерное общество "АЛРОСА-Нюрба"',
#      'emitent_inn': '1419003844',
#      'emitent_okpo': None,
#      'gosreg': '1-01-20179-F',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 8094,
#      'secid': 'ALRS',
#      'shortname': 'АЛРОСА ао',
#      'regnumber': '1-03-40046-N',
#      'name': 'АЛРОСА ПАО ао',
#      'isin': 'RU0007252813',
#      'is_traded': 1,
#      'emitent_id': 1246,
#      'emitent_title': 'Акционерная компания "АЛРОСА" (публичное акционерное общество)',
#      'emitent_inn': '1433000147',
#      'emitent_okpo': '23308410',
#      'gosreg': '1-03-40046-N',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 261761279,
#      'secid': 'ALU0',
#      'shortname': 'ALRS-9.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALRS-9.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': 1246,
#      'emitent_title': 'Акционерная компания "АЛРОСА" (публичное акционерное общество)',
#      'emitent_inn': '1433000147',
#      'emitent_okpo': '23308410',
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 261761281,
#      'secid': 'ALZ0',
#      'shortname': 'ALRS-12.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALRS-12.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': 1246,
#      'emitent_title': 'Акционерная компания "АЛРОСА" (публичное акционерное общество)',
#      'emitent_inn': '1433000147',
#      'emitent_okpo': '23308410',
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 6442,
#      'secid': 'AMEZ',
#      'shortname': 'АшинскийМЗ',
#      'regnumber': '1-03-45219-D',
#      'name': ' Ашинский метзавод ПАО ао',
#      'isin': 'RU000A0B88G6',
#      'is_traded': 1,
#      'emitent_id': 2163,
#      'emitent_title': 'Публичное акционерное общество "Ашинский металлургический завод"',
#      'emitent_inn': '7401000473',
#      'emitent_okpo': '00186447',
#      'gosreg': '1-03-45219-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 261761283,
#      'secid': 'AMK0',
#      'shortname': 'ALMN-5.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALMN-5.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 290185313,
#      'secid': 'AMM0',
#      'shortname': 'ALMN-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALMN-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 328981145,
#      'secid': 'AMN0',
#      'shortname': 'ALMN-7.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALMN-7.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 379334647,
#      'secid': 'AMQ0',
#      'shortname': 'ALMN-8.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт ALMN-8.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 154677,
#      'secid': 'AMZN',
#      'shortname': 'Amazon',
#      'regnumber': None,
#      'name': 'Amazon.com Inc.',
#      'isin': 'US0231351067',
#      'is_traded': 1,
#      'emitent_id': 1281005,
#      'emitent_title': 'Amazon.com, Inc.',
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'EQRD',
#      'marketprice_boardid': None},
#     {'id': 8052,
#      'secid': 'APTK',
#      'shortname': 'Аптеки36и6',
#      'regnumber': '1-01-07335-A',
#      'name': 'ПАО "Аптечная сеть 36,6" ао',
#      'isin': 'RU0008081765',
#      'is_traded': 1,
#      'emitent_id': 1619,
#      'emitent_title': 'Публичное акционерное общество "Аптечная сеть 36,6"',
#      'emitent_inn': '7722266450',
#      'emitent_okpo': '59055031',
#      'gosreg': '1-01-07335-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 84864,
#      'secid': 'AQUA',
#      'shortname': 'РусАква ао',
#      'regnumber': '1-01-04461-D',
#      'name': 'Русская Аквакультура ПАО ао',
#      'isin': 'RU000A0JQTS3',
#      'is_traded': 1,
#      'emitent_id': 2319,
#      'emitent_title': 'Публичное  акционерное общество "Русская Аквакультура"',
#      'emitent_inn': '7816430057',
#      'emitent_okpo': '83783293',
#      'gosreg': '1-01-04461-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 6115,
#      'secid': 'ARSA',
#      'shortname': 'Арсагера',
#      'regnumber': '1-01-03163-D',
#      'name': 'УК Арсагера ПАО-ао',
#      'isin': 'RU000A0JP0Q7',
#      'is_traded': 1,
#      'emitent_id': 1937,
#      'emitent_title': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "УПРАВЛЯЮЩАЯ КОМПАНИЯ "АРСАГЕРА"',
#      'emitent_inn': '7840303927',
#      'emitent_okpo': '73405555',
#      'gosreg': '1-01-03163-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 2710,
#      'secid': 'ASSB',
#      'shortname': 'АстрЭнСб',
#      'regnumber': '1-01-55064-E',
#      'name': '"Астраханская ЭСК" ПАО',
#      'isin': 'RU000A0D8MM8',
#      'is_traded': 1,
#      'emitent_id': 1823,
#      'emitent_title': 'Публичное акционерное общество "Астраханская энергосбытовая компания"',
#      'emitent_inn': '3017041554',
#      'emitent_okpo': None,
#      'gosreg': '1-01-55064-E',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 81989,
#      'secid': 'ATAD-ME',
#      'shortname': 'ATAD-адр',
#      'regnumber': None,
#      'name': 'ГДР ао Татнефть ORD SHS',
#      'isin': 'US8766292051',
#      'is_traded': 1,
#      'emitent_id': 328873,
#      'emitent_title': 'Bank of New York Mellon Corporation (Американская депозитарная расписка на ао ОАО "Татнефть" им. В.Д. Шашина)',
#      'emitent_inn': '1000004032',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'depositary_receipt',
#      'group': 'stock_dr',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 211391369,
#      'secid': 'AUM0',
#      'shortname': 'AUDU-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт AUDU-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 290185317,
#      'secid': 'AUU0',
#      'shortname': 'AUDU-9.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт AUDU-9.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 141068,
#      'secid': 'AVAG',
#      'shortname': 'АванАгр-ао',
#      'regnumber': None,
#      'name': 'Авангард-Агро АО ао',
#      'isin': 'RU000A0JWMY4',
#      'is_traded': 1,
#      'emitent_id': 192283,
#      'emitent_title': 'Акционерное общество "АВАНГАРД-АГРО"',
#      'emitent_inn': '5722033117',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 14429,
#      'secid': 'AVAN',
#      'shortname': 'Авангрд-ао',
#      'regnumber': '10102879B',
#      'name': 'АКБ "АВАНГАРД" ПАО ао',
#      'isin': 'RU000A0DM7B3',
#      'is_traded': 1,
#      'emitent_id': 1228,
#      'emitent_title': 'Акционерный Коммерческий банк "АВАНГАРД" - публичное акционерное общество',
#      'emitent_inn': '7702021163',
#      'emitent_okpo': '29304028',
#      'gosreg': '10102879B',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 68330,
#      'secid': 'AVGR-ME',
#      'shortname': 'AVGR-гдр',
#      'regnumber': None,
#      'name': 'ГДР Avangardco Invest ORD SHS',
#      'isin': 'US05349V2097',
#      'is_traded': 1,
#      'emitent_id': 4184,
#      'emitent_title': 'Bank of New York Mellon Corporation (Avangardco Investments Public Limited)',
#      'emitent_inn': '1000003803',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'depositary_receipt',
#      'group': 'stock_dr',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 86199,
#      'secid': 'avsk',
#      'shortname': 'ОАО "ТАВС "Кубань"',
#      'regnumber': '1-01-34643-E',
#      'name': 'Открытое Акционерное Общество "Территориальное агентство воздушных сообщений "Кубань"',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': 487471,
#      'emitent_title': 'Открытое Акционерное Общество "Территориальное агентство воздушных сообщений "Кубань"',
#      'emitent_inn': '2312126436',
#      'emitent_okpo': None,
#      'gosreg': '1-01-34643-E',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 189757877,
#      'secid': 'AWTEUR',
#      'shortname': 'TINKOFF ALL-WEATHER INDEX (EUR)',
#      'regnumber': None,
#      'name': 'TINKOFF ALL-WEATHER INDEX (EUR)',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'RTSI',
#      'marketprice_boardid': None},
#     {'id': 189757873,
#      'secid': 'AWTRUR',
#      'shortname': 'TINKOFF ALL-WEATHER INDEX (RUB)',
#      'regnumber': None,
#      'name': 'TINKOFF ALL-WEATHER INDEX (RUB)',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'RTSI',
#      'marketprice_boardid': None},
#     {'id': 189757875,
#      'secid': 'AWTUSD',
#      'shortname': 'TINKOFF ALL-WEATHER INDEX (USD)',
#      'regnumber': None,
#      'name': 'TINKOFF ALL-WEATHER INDEX (USD)',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'stock_index',
#      'group': 'stock_index',
#      'primary_boardid': 'RTSI',
#      'marketprice_boardid': None},
#     {'id': 164599,
#      'secid': 'BA',
#      'shortname': 'Boeing',
#      'regnumber': None,
#      'name': 'The Boeing Company',
#      'isin': 'US0970231058',
#      'is_traded': 1,
#      'emitent_id': 1341526,
#      'emitent_title': 'The Boeing Company',
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'EQRD',
#      'marketprice_boardid': None},
#     {'id': 164600,
#      'secid': 'BABA',
#      'shortname': 'AlibabaADR',
#      'regnumber': None,
#      'name': 'Alibaba ADR',
#      'isin': 'US01609W1027',
#      'is_traded': 1,
#      'emitent_id': 1341530,
#      'emitent_title': 'Citibank N.A. (АДР Alibaba)',
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'depositary_receipt',
#      'group': 'stock_dr',
#      'primary_boardid': 'EQRD',
#      'marketprice_boardid': None},
#     {'id': 8048,
#      'secid': 'BANE',
#      'shortname': 'Башнефт ао',
#      'regnumber': '1-01-00013-A',
#      'name': 'Башнефть АНК ао',
#      'isin': 'RU0007976957',
#      'is_traded': 1,
#      'emitent_id': 2267,
#      'emitent_title': 'Публичное акционерное общество "Акционерная нефтяная Компания "Башнефть"',
#      'emitent_inn': '0274051582',
#      'emitent_okpo': '00135645',
#      'gosreg': '1-01-00013-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 8049,
#      'secid': 'BANEP',
#      'shortname': 'Башнефт ап',
#      'regnumber': '2-01-00013-A',
#      'name': 'Башнефть АНК ап',
#      'isin': 'RU0007976965',
#      'is_traded': 1,
#      'emitent_id': 2267,
#      'emitent_title': 'Публичное акционерное общество "Акционерная нефтяная Компания "Башнефть"',
#      'emitent_inn': '0274051582',
#      'emitent_okpo': '00135645',
#      'gosreg': '2-01-00013-A',
#      'type': 'preferred_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 132432,
#      'secid': 'BELU',
#      'shortname': 'Белуга ао',
#      'regnumber': '1-01-55052-E',
#      'name': 'Белуга Групп ПАО ао',
#      'isin': 'RU000A0HL5M1',
#      'is_traded': 1,
#      'emitent_id': 1596,
#      'emitent_title': 'Публичное акционерное общество "Белуга Групп"',
#      'emitent_inn': '7705634425',
#      'emitent_okpo': '75353667',
#      'gosreg': '1-01-55052-E',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 164601,
#      'secid': 'BIDU',
#      'shortname': 'BaiduADR',
#      'regnumber': None,
#      'name': 'Baidu ADR, Inc. ORD SHS',
#      'isin': 'US0567521085',
#      'is_traded': 1,
#      'emitent_id': 1341532,
#      'emitent_title': 'The Bank of New York Mellon (АДР Baidu, Inc. ORD SHS)',
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'depositary_receipt',
#      'group': 'stock_dr',
#      'primary_boardid': 'EQRD',
#      'marketprice_boardid': None},
#     {'id': 7183,
#      'secid': 'BISV',
#      'shortname': 'БашИнСв ао',
#      'regnumber': '1-01-00011-A',
#      'name': 'Башинформсвязь(ПАО) ао',
#      'isin': 'RU0009059216',
#      'is_traded': 1,
#      'emitent_id': 1307,
#      'emitent_title': 'Публичное акционерное общество "Башинформсвязь"',
#      'emitent_inn': '0274018377',
#      'emitent_okpo': '01150144',
#      'gosreg': '1-01-00011-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 7184,
#      'secid': 'BISVP',
#      'shortname': 'БашИнСв ап',
#      'regnumber': '2-01-00011-A',
#      'name': 'Башинформсвязь(ПАО) ап',
#      'isin': 'RU0009100176',
#      'is_traded': 1,
#      'emitent_id': 1307,
#      'emitent_title': 'Публичное акционерное общество "Башинформсвязь"',
#      'emitent_inn': '0274018377',
#      'emitent_okpo': '01150144',
#      'gosreg': '2-01-00011-A',
#      'type': 'preferred_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 2711,
#      'secid': 'BLNG',
#      'shortname': 'Белон ао',
#      'regnumber': '1-06-10167-F',
#      'name': 'Белон ОАО ао',
#      'isin': 'RU000A0J2QG8',
#      'is_traded': 1,
#      'emitent_id': 2132,
#      'emitent_title': 'Открытое акционерное общество "Белон"',
#      'emitent_inn': '5410102823',
#      'emitent_okpo': '11820893',
#      'gosreg': '1-06-10167-F',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 85981,
#      'secid': 'bmkk',
#      'shortname': 'АО "БМК"',
#      'regnumber': '1-01-30269-D',
#      'name': 'Акционерное общество "Белорецкий металлургический комбинат"',
#      'isin': 'RU0005419117',
#      'is_traded': 1,
#      'emitent_id': 487004,
#      'emitent_title': 'Акционерное общество "Белорецкий металлургический комбинат"',
#      'emitent_inn': '0256006322',
#      'emitent_okpo': None,
#      'gosreg': '1-01-30269-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 85996,
#      'secid': 'bogz',
#      'shortname': 'ОАО "Газпром газораспределение Белгород"',
#      'regnumber': '1-01-40034-A',
#      'name': 'Открытое акционерное общество "Газпром газораспределение Белгород"',
#      'isin': 'RU000A0JRF86',
#      'is_traded': 1,
#      'emitent_id': 487051,
#      'emitent_title': 'Акционерное общество "Газпром газораспределение Белгород"',
#      'emitent_inn': '3124010222',
#      'emitent_okpo': None,
#      'gosreg': '1-01-40034-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 86006,
#      'secid': 'borg',
#      'shortname': 'ОАО " Эй Джи Си БСЗ"',
#      'regnumber': '1-04-00015-A',
#      'name': 'Открытое акционерное общество "Эй Джи Си Борский стекольный завод"',
#      'isin': 'RU0009097265',
#      'is_traded': 1,
#      'emitent_id': 486938,
#      'emitent_title': 'Открытое акционерное общество "Эй Джи Си Борский стекольный завод"',
#      'emitent_inn': '5246002261',
#      'emitent_okpo': None,
#      'gosreg': '1-04-00015-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 164602,
#      'secid': 'BP',
#      'shortname': 'BP PLCADR',
#      'regnumber': None,
#      'name': 'BP PLC ADR ORD SHS',
#      'isin': 'US0556221044',
#      'is_traded': 1,
#      'emitent_id': 1341534,
#      'emitent_title': 'JPMORGAN CHASE BANK, NATIONAL ASSOCIATION (АДР BP PLC ORD SHS)',
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'depositary_receipt',
#      'group': 'stock_dr',
#      'primary_boardid': 'EQRD',
#      'marketprice_boardid': None},
#     {'id': 86240,
#      'secid': 'brad',
#      'shortname': 'ОАО "Богословское рудоуправление"',
#      'regnumber': '1-01-31376-D',
#      'name': 'Открытое акционерное общество "Богословское рудоуправление"',
#      'isin': 'RU000A0JPEW9',
#      'is_traded': 1,
#      'emitent_id': 487007,
#      'emitent_title': 'Открытое акционерное общество "Богословское рудоуправление"',
#      'emitent_inn': '6617002344',
#      'emitent_okpo': None,
#      'gosreg': '1-01-31376-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 33925,
#      'secid': 'BRF1',
#      'shortname': 'BR-1.21',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-1.21',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33932,
#      'secid': 'BRG1',
#      'shortname': 'BR-2.21',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-2.21',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33949,
#      'secid': 'BRH1',
#      'shortname': 'BR-3.21',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-3.21',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33985,
#      'secid': 'BRJ1',
#      'shortname': 'BR-4.21',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-4.21',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 34001,
#      'secid': 'BRK1',
#      'shortname': 'BR-5.21',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-5.21',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33820,
#      'secid': 'BRM0',
#      'shortname': 'BR-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33826,
#      'secid': 'BRN0',
#      'shortname': 'BR-7.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-7.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 86007,
#      'secid': 'brog',
#      'shortname': 'АО "Газпром газораспределение Брянск"',
#      'regnumber': '1-01-42140-A',
#      'name': 'Акционерное общество "Газпром газораспределение Брянск"',
#      'isin': 'RU0009121131',
#      'is_traded': 1,
#      'emitent_id': 487052,
#      'emitent_title': 'Акционерное общество "Газпром газораспределение Брянск"',
#      'emitent_inn': '3234007455',
#      'emitent_okpo': None,
#      'gosreg': '1-01-42140-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 33828,
#      'secid': 'BRQ0',
#      'shortname': 'BR-8.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-8.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 85885,
#      'secid': 'brsz',
#      'shortname': 'АО "БСЗ"',
#      'regnumber': '1-01-30667-D',
#      'name': 'Акционерное общество "Березниковский содовый завод"',
#      'isin': 'RU000A0JQTK0',
#      'is_traded': 1,
#      'emitent_id': 486907,
#      'emitent_title': 'Акционерное общество "Березниковский содовый завод"',
#      'emitent_inn': '5911013780',
#      'emitent_okpo': None,
#      'gosreg': '1-01-30667-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 85886,
#      'secid': 'brszp',
#      'shortname': 'АО "БСЗ"',
#      'regnumber': '2-01-30667-D',
#      'name': 'Акционерное общество "Березниковский содовый завод"',
#      'isin': 'RU000A0JQTL8',
#      'is_traded': 1,
#      'emitent_id': 486907,
#      'emitent_title': 'Акционерное общество "Березниковский содовый завод"',
#      'emitent_inn': '5911013780',
#      'emitent_okpo': None,
#      'gosreg': '2-01-30667-D',
#      'type': 'preferred_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 33860,
#      'secid': 'BRU0',
#      'shortname': 'BR-9.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-9.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33871,
#      'secid': 'BRV0',
#      'shortname': 'BR-10.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-10.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33878,
#      'secid': 'BRX0',
#      'shortname': 'BR-11.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-11.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 33905,
#      'secid': 'BRZ0',
#      'shortname': 'BR-12.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт BR-12.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 8132,
#      'secid': 'BRZL',
#      'shortname': 'БурЗолото',
#      'regnumber': '1-06-20577-F',
#      'name': 'Бурятзолото ПАО ао',
#      'isin': 'RU0009288658',
#      'is_traded': 1,
#      'emitent_id': 2479,
#      'emitent_title': 'Публичное акционерное общество "Бурятзолото"',
#      'emitent_inn': '0323027345',
#      'emitent_okpo': None,
#      'gosreg': '1-06-20577-F',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 86243,
#      'secid': 'brzlp',
#      'shortname': 'ПАО "Бурятзолото"',
#      'regnumber': '3-03-20577-F',
#      'name': 'Публичное акционерное общество "Бурятзолото"',
#      'isin': 'RU0007964763',
#      'is_traded': 1,
#      'emitent_id': 2479,
#      'emitent_title': 'Публичное акционерное общество "Бурятзолото"',
#      'emitent_inn': '0323027345',
#      'emitent_okpo': None,
#      'gosreg': '3-03-20577-F',
#      'type': 'preferred_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 6104,
#      'secid': 'BSPB',
#      'shortname': 'БСП ао',
#      'regnumber': '10300436B',
#      'name': 'ПАО "Банк "Санкт-Петербург" ао',
#      'isin': 'RU0009100945',
#      'is_traded': 1,
#      'emitent_id': 1997,
#      'emitent_title': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "БАНК "САНКТ-ПЕТЕРБУРГ"',
#      'emitent_inn': '7831000027',
#      'emitent_okpo': '09804728',
#      'gosreg': '10300436B',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 7063,
#      'secid': 'BSPBP',
#      'shortname': 'БСП ап',
#      'regnumber': 'None',
#      'name': 'ПАО "Банк "Санкт-Петербург" ап',
#      'isin': 'RU000A0JP0U9',
#      'is_traded': 1,
#      'emitent_id': 1997,
#      'emitent_title': 'ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "БАНК "САНКТ-ПЕТЕРБУРГ"',
#      'emitent_inn': '7831000027',
#      'emitent_okpo': '09804728',
#      'gosreg': 'None',
#      'type': 'preferred_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 85889,
#      'secid': 'btst',
#      'shortname': 'ОАО "Бамтоннельстрой"',
#      'regnumber': '1-01-21060-F',
#      'name': 'Открытое акционерное общество "Бамтоннельстрой"',
#      'isin': 'RU000A0JNM24',
#      'is_traded': 1,
#      'emitent_id': 486986,
#      'emitent_title': 'Акционерное общество "Бамтоннельстрой"',
#      'emitent_inn': '0317000144',
#      'emitent_okpo': None,
#      'gosreg': '1-01-21060-F',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 86252,
#      'secid': 'btstp',
#      'shortname': 'ОАО "Бамтоннельстрой"',
#      'regnumber': '2-01-21060-F',
#      'name': 'Открытое акционерное общество "Бамтоннельстрой"',
#      'isin': 'RU000A0JNM32',
#      'is_traded': 1,
#      'emitent_id': 486986,
#      'emitent_title': 'Акционерное общество "Бамтоннельстрой"',
#      'emitent_inn': '0317000144',
#      'emitent_okpo': None,
#      'gosreg': '2-01-21060-F',
#      'type': 'preferred_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 301667429,
#      'secid': 'BWM0',
#      'shortname': 'GBMW-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт GBMW-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 108133,
#      'secid': 'BYNRUBTODTOM',
#      'shortname': 'BYN_TODTOM',
#      'regnumber': None,
#      'name': 'BYN_TODTOM - СВОП BYN/РУБ',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'currency',
#      'group': 'currency_selt',
#      'primary_boardid': 'CETS',
#      'marketprice_boardid': None},
#     {'id': 108131,
#      'secid': 'BYNRUB_TOD',
#      'shortname': 'BYNRUB_TOD',
#      'regnumber': None,
#      'name': 'BYN/RUB_TOD - BYN/РУБ',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'currency',
#      'group': 'currency_selt',
#      'primary_boardid': 'CETS',
#      'marketprice_boardid': None},
#     {'id': 108132,
#      'secid': 'BYNRUB_TOM',
#      'shortname': 'BYNRUB_TOM',
#      'regnumber': None,
#      'name': 'BYN/RUB_TOM - BYN/РУБ',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'currency',
#      'group': 'currency_selt',
#      'primary_boardid': 'CETS',
#      'marketprice_boardid': None},
#     {'id': 211391371,
#      'secid': 'CAM0',
#      'shortname': 'UCAD-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт UCAD-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 290185321,
#      'secid': 'CAU0',
#      'shortname': 'UCAD-9.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт UCAD-9.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 85628,
#      'secid': 'CBOM',
#      'shortname': 'МКБ ао',
#      'regnumber': '10101978B',
#      'name': '"МКБ" ПАО ао',
#      'isin': 'RU000A0JUG31',
#      'is_traded': 1,
#      'emitent_id': 1210,
#      'emitent_title': '"МОСКОВСКИЙ КРЕДИТНЫЙ БАНК" (публичное акционерное общество)',
#      'emitent_inn': '7734202860',
#      'emitent_okpo': '09318941',
#      'gosreg': '10101978B',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 86261,
#      'secid': 'ccsg',
#      'shortname': 'ПАО "ККС-Групп"',
#      'regnumber': '1-01-55462-E',
#      'name': 'Публичное акционерное общество "Группа компаний коммунальной сферы"',
#      'isin': 'RU000A0JQGV4',
#      'is_traded': 1,
#      'emitent_id': 487162,
#      'emitent_title': 'Публичное акционерное общество "Группа компаний коммунальной сферы"',
#      'emitent_inn': '7730183529',
#      'emitent_okpo': None,
#      'gosreg': '1-01-55462-E',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 211391373,
#      'secid': 'CFM0',
#      'shortname': 'UCHF-6.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт UCHF-6.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 290185325,
#      'secid': 'CFU0',
#      'shortname': 'UCHF-9.20',
#      'regnumber': None,
#      'name': 'Фьючерсный контракт UCHF-9.20',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'futures',
#      'group': 'futures_forts',
#      'primary_boardid': 'RFUD',
#      'marketprice_boardid': None},
#     {'id': 89030,
#      'secid': 'CH0205819441',
#      'shortname': 'RZD-21 CHF',
#      'regnumber': None,
#      'name': 'RZD Capital PLC 21 CHF',
#      'isin': 'CH0205819441',
#      'is_traded': 1,
#      'emitent_id': 68224,
#      'emitent_title': 'RZD Capital plc',
#      'emitent_inn': '0000003850',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 146181,
#      'secid': 'CH0248531110',
#      'shortname': 'VTB-24 CHF',
#      'regnumber': None,
#      'name': 'VTB CAPITAL S.A. 24 CHF',
#      'isin': 'CH0248531110',
#      'is_traded': 1,
#      'emitent_id': 68213,
#      'emitent_title': 'VTB Capital S.A',
#      'emitent_inn': '0000097053',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 128625,
#      'secid': 'CH0346828400',
#      'shortname': 'GAZ-21 CHF',
#      'regnumber': None,
#      'name': 'GAZ CAPITAL SA 2.75 30/11/21',
#      'isin': 'CH0346828400',
#      'is_traded': 1,
#      'emitent_id': 68219,
#      'emitent_title': 'Gaz Capital S.A.',
#      'emitent_inn': '0000095071',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 146182,
#      'secid': 'CH0374882816',
#      'shortname': 'GAZ-22 CHF',
#      'regnumber': None,
#      'name': 'GAZ CAPITAL SA 2.25 19/07/22',
#      'isin': 'CH0374882816',
#      'is_traded': 1,
#      'emitent_id': 68219,
#      'emitent_title': 'Gaz Capital S.A.',
#      'emitent_inn': '0000095071',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 138904,
#      'secid': 'CH0379268748',
#      'shortname': 'RZD-23 CHF',
#      'regnumber': None,
#      'name': 'RZD Capital PLC 23 CHF',
#      'isin': 'CH0379268748',
#      'is_traded': 1,
#      'emitent_id': 68224,
#      'emitent_title': 'RZD Capital plc',
#      'emitent_inn': '0000003850',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 156232573,
#      'secid': 'CH0385518086',
#      'shortname': 'ALFA-22 CH',
#      'regnumber': None,
#      'name': 'Alfa Holding Issuance 09/11/22',
#      'isin': 'CH0385518086',
#      'is_traded': 1,
#      'emitent_id': 209908,
#      'emitent_title': 'Alfa holding Issuance plc',
#      'emitent_inn': '0000003953',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 151595,
#      'secid': 'CH0404311711',
#      'shortname': 'GAZ-23 CHF',
#      'regnumber': None,
#      'name': 'GAZ CAPITAL SA 1.45 6/3/23 CHF',
#      'isin': 'CH0404311711',
#      'is_traded': 1,
#      'emitent_id': 68219,
#      'emitent_title': 'Gaz Capital S.A.',
#      'emitent_inn': '0000095071',
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'corporate_bond',
#      'group': 'stock_bonds',
#      'primary_boardid': 'RPMO',
#      'marketprice_boardid': None},
#     {'id': 85904,
#      'secid': 'chaz',
#      'shortname': 'ОАО "ЧАЗ"',
#      'regnumber': '1-01-55127-D',
#      'name': 'Открытое акционерное общество "Чебоксарский агрегатный завод"',
#      'isin': 'RU000A0F5V95',
#      'is_traded': 1,
#      'emitent_id': 487571,
#      'emitent_title': 'Публичное акционерное общество "Чебоксарский агрегатный завод"',
#      'emitent_inn': '2126001687',
#      'emitent_okpo': None,
#      'gosreg': '1-01-55127-D',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'MXBD',
#      'marketprice_boardid': None},
#     {'id': 6599,
#      'secid': 'CHEP',
#      'shortname': 'ЧТПЗ ао',
#      'regnumber': '1-01-00182-A',
#      'name': '"ЧТПЗ" ПАО ао',
#      'isin': 'RU0009066807',
#      'is_traded': 1,
#      'emitent_id': 1477,
#      'emitent_title': 'Публичное акционерное общество "Челябинский трубопрокатный завод"',
#      'emitent_inn': '7449006730',
#      'emitent_okpo': '00186654',
#      'gosreg': '1-01-00182-A',
#      'type': 'common_share',
#      'group': 'stock_shares',
#      'primary_boardid': 'TQBR',
#      'marketprice_boardid': 'TQBR'},
#     {'id': 108357,
#      'secid': 'CHFRUBTODTOM',
#      'shortname': 'CHF_TODTOM',
#      'regnumber': None,
#      'name': 'CHF_TODTOM - СВОП CHF/РУБ',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'currency',
#      'group': 'currency_selt',
#      'primary_boardid': 'CETS',
#      'marketprice_boardid': None},
#     {'id': 108355,
#      'secid': 'CHFRUB_TOD',
#      'shortname': 'CHFRUB_TOD',
#      'regnumber': None,
#      'name': 'CHF/RUB_TOD - CHF/РУБ',
#      'isin': None,
#      'is_traded': 1,
#      'emitent_id': None,
#      'emitent_title': None,
#      'emitent_inn': None,
#      'emitent_okpo': None,
#      'gosreg': None,
#      'type': 'currency',
#      'group': 'currency_selt',
#      'primary_boardid': 'CETS',
#      'marketprice_boardid': None}]]}]
